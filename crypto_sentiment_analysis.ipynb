# %% [markdown]
# <h1 style="font-size:3rem;">App Sentiment Analysis</h1>
# <h3 style="font-size:2rem;">Extract reviews for various apps</h3>
# <h5 style="font-size:1rem;">Catima — Loyalty Card Wallet</h5>

# %%
# !pip install google-play-scraper
# !pip install pandas numpy plotly
# Out:
# Requirement already satisfied: google-play-scraper in /usr/local/lib/python3.11/dist-packages (1.2.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (1.26.4)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (5.24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly) (9.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly) (24.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
pip install pyyaml
# Out:
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (6.0.2)

# %%
import pandas as pd
import numpy as np
import time
from google_play_scraper import app, Sort, reviews_all
import plotly.express as px

# %%
app_id = 'me.hackerchick.catima'
reviews = reviews_all(
    app_id,
    sleep_milliseconds=0,
    lang='en',
    country='US',
    sort=Sort.NEWEST
)

if not reviews:
    print("No reviews found for the specified app ID.")
else:
    # Parse reviews
    parsed_reviews = []
    for review in reviews:
        reviewer_name = review.get('userName', '')
        review_text = review.get('content', '')
        rating = review.get('score', '')
        parsed_reviews.append({
            'Reviewer Name': reviewer_name,
            'Review Text': review_text,
            'Rating': rating
        })

    df = pd.DataFrame(parsed_reviews)

    file_name = "Catima_Reviews.csv"
    df.to_csv(file_name, index=False)
    print(f"CSV file '{file_name}' has been created successfully.")
# Out:
# CSV file 'Catima_Reviews.csv' has been created successfully.

# %% [markdown]
# <h5 style="font-size:1rem;">Stocard - Rewards Cards Wallet</h5>

# %%
def fetch_reviews(app_id, min_reviews=1000, retry_attempts=3):
    fetched_reviews = []
    total_reviews = 0

    for attempt in range(1, retry_attempts + 1):
        try:
            while total_reviews < min_reviews:
                # Fetch reviews in batches
                reviews = reviews_all(
                    app_id,
                    sleep_milliseconds=0,
                    lang='en',
                    country='US',
                    sort=Sort.NEWEST,
                    count=min_reviews - total_reviews
                )

                if not reviews:
                    break

                parsed_reviews = []
                for review in reviews:
                    reviewer_name = review['userName']
                    review_text = review['content']
                    rating = review['score']
                    parsed_reviews.append({
                        'Reviewer Name': reviewer_name,
                        'Review Text': review_text,
                        'Rating': rating
                    })

                total_reviews += len(parsed_reviews)
                fetched_reviews.extend(parsed_reviews)
                print(f"Fetched {total_reviews} reviews...")
                if total_reviews >= min_reviews:
                    break

            df = pd.DataFrame(fetched_reviews)
            file_name = "Stocard_reviews.csv"
            df.to_csv(file_name, index=False)
            print(f"CSV file '{file_name}' has been created successfully.")

            return True  # Reviews fetched successfully

        except Exception as e:
            print(f"Attempt {attempt}/{retry_attempts} failed. Error: {e}")
            if attempt < retry_attempts:
                print("Retrying after 5 seconds...")
                time.sleep(5)
            else:
                print("All retry attempts failed. Unable to fetch reviews.")
                return False  # Failed to fetch reviews

app_id = 'de.stocard.stocard'
fetch_reviews(app_id, min_reviews=1000)
# Out:
# Fetched 46929 reviews...
# CSV file 'Stocard_reviews.csv' has been created successfully.
# True

# %% [markdown]
# <h5 style="font-size:1rem;">Key Ring: Loyalty Card App</h5>

# %%
def fetch_reviews(app_id, min_reviews=1000, retry_attempts=3):
    fetched_reviews = []
    total_reviews = 0

    for attempt in range(1, retry_attempts + 1):
        try:
            while total_reviews < min_reviews:
                # Fetch reviews in batches
                reviews = reviews_all(
                    app_id,
                    sleep_milliseconds=0,
                    lang='en',
                    country='US',
                    sort=Sort.NEWEST,
                    count=min_reviews - total_reviews
                )

                if not reviews:
                    break

                parsed_reviews = []
                for review in reviews:
                    reviewer_name = review['userName']
                    review_text = review['content']
                    rating = review['score']
                    parsed_reviews.append({
                        'Reviewer Name': reviewer_name,
                        'Review Text': review_text,
                        'Rating': rating
                    })

                total_reviews += len(parsed_reviews)
                fetched_reviews.extend(parsed_reviews)
                print(f"Fetched {total_reviews} reviews...")
                if total_reviews >= min_reviews:
                    break

            df = pd.DataFrame(fetched_reviews)
            file_name = "KeyRing_reviews.csv"
            df.to_csv(file_name, index=False)
            print(f"CSV file '{file_name}' has been created successfully.")

            return True  # Reviews fetched successfully

        except Exception as e:
            print(f"Attempt {attempt}/{retry_attempts} failed. Error: {e}")
            if attempt < retry_attempts:
                print("Retrying after 5 seconds...")
                time.sleep(5)
            else:
                print("All retry attempts failed. Unable to fetch reviews.")
                return False  # Failed to fetch reviews

app_id = 'com.froogloid.kring.google.zxing.client.android'
fetch_reviews(app_id, min_reviews=1000)
# Out:
# Fetched 12981 reviews...
# CSV file 'KeyRing_reviews.csv' has been created successfully.
# True

# %% [markdown]
# <h5 style="font-size:1rem;">FidMe Loyalty Cards & Cashback</h5>

# %%
def fetch_reviews(app_id, min_reviews=1000, retry_attempts=3):
    fetched_reviews = []
    total_reviews = 0  #

    for attempt in range(1, retry_attempts + 1):
        try:
            while total_reviews < min_reviews:
                # Fetch reviews in batches
                reviews = reviews_all(
                    app_id,
                    sleep_milliseconds=0,
                    lang='en',
                    country='US',
                    sort=Sort.NEWEST,
                    count=min_reviews - total_reviews
                )

                if not reviews:
                    break

                parsed_reviews = []
                for review in reviews:
                    reviewer_name = review['userName']
                    review_text = review['content']
                    rating = review['score']
                    parsed_reviews.append({
                        'Reviewer Name': reviewer_name,
                        'Review Text': review_text,
                        'Rating': rating
                    })

                total_reviews += len(parsed_reviews)
                fetched_reviews.extend(parsed_reviews)
                print(f"Fetched {total_reviews} reviews...")

                if total_reviews >= min_reviews:
                    break

            df = pd.DataFrame(fetched_reviews)
            file_name = "FidMe_reviews.csv"
            df.to_csv(file_name, index=False)
            print(f"CSV file '{file_name}' has been created successfully.")

            return True

        except Exception as e:
            print(f"Attempt {attempt}/{retry_attempts} failed. Error: {e}")
            if attempt < retry_attempts:
                print("Retrying after 5 seconds...")
                time.sleep(5)
            else:
                print("All retry attempts failed. Unable to fetch reviews.")
                return False  # Failed to fetch reviews

app_id = 'fr.snapp.fidme'
fetch_reviews(app_id, min_reviews=1350)
# Out:
# Fetched 726 reviews...
# Fetched 1452 reviews...
# CSV file 'FidMe_reviews.csv' has been created successfully.
# True

# %% [markdown]
# <h5 style="font-size:1rem;">Pass2U Wallet - digitize cards</h5>

# %%
def fetch_reviews(app_id, min_reviews=1000, retry_attempts=3):
    fetched_reviews = []
    total_reviews = 0

    for attempt in range(1, retry_attempts + 1):
        try:
            while total_reviews < min_reviews:
                # Fetch reviews in batches
                reviews = reviews_all(
                    app_id,
                    sleep_milliseconds=0,
                    lang='en',
                    country='US',
                    sort=Sort.NEWEST,
                    count=min_reviews - total_reviews
                )

                if not reviews:
                    break

                parsed_reviews = []
                for review in reviews:
                    reviewer_name = review['userName']
                    review_text = review['content']
                    rating = review['score']
                    parsed_reviews.append({
                        'Reviewer Name': reviewer_name,
                        'Review Text': review_text,
                        'Rating': rating
                    })

                total_reviews += len(parsed_reviews)
                fetched_reviews.extend(parsed_reviews)
                print(f"Fetched {total_reviews} reviews...")
                if total_reviews >= min_reviews:
                    break

            df = pd.DataFrame(fetched_reviews)
            file_name = "Pass2U_reviews.csv"
            df.to_csv(file_name, index=False)
            print(f"CSV file '{file_name}' has been created successfully.")
            return True

        except Exception as e:
            print(f"Attempt {attempt}/{retry_attempts} failed. Error: {e}")
            if attempt < retry_attempts:
                print("Retrying after 5 seconds...")
                time.sleep(5)
            else:
                print("All retry attempts failed. Unable to fetch reviews.")
                return False  # Failed to fetch reviews

# Example usage
app_id = 'com.passesalliance.wallet'
fetch_reviews(app_id, min_reviews=1000)
# Out:
# Fetched 1155 reviews...
# CSV file 'Pass2U_reviews.csv' has been created successfully.
# True

# %% [markdown]
# <h3 style="font-size:2rem;">Processing words in reviews</h3>

# %% [markdown]
# <h5 style="font-size:1rem;">Stocard - Rewards Cards Wallet</h5>

# %%
# !pip install num2words
# !pip install nltk
# Out:
# Requirement already satisfied: num2words in /usr/local/lib/python3.11/dist-packages (0.5.14)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.11/dist-packages (from num2words) (0.6.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk) (4.67.1)

# %%
import pandas as pd
import re
import string
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from num2words import num2words

# Download nltk resources
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Function to preprocess text
def preprocess_text(text):
    if isinstance(text, str):
        # Remove punctuations
        text = text.translate(str.maketrans('', '', string.punctuation))

        # Remove special characters and emojis
        text = re.sub(r'[^\w\s]', '', text)

        # Turn numbers into text
        words = []
        for word in nltk.word_tokenize(text):
            if re.fullmatch(r"\d+(\.\d+)?", word):
                try:
                    words.append(num2words(float(word)))
                except (InvalidOperation, ValueError):
                    words.append(word)
            else:
                words.append(word)
        text = ' '.join(words)

        # Remove extra white spaces
        text = ' '.join(text.split())

        # Turn all words into lowercase
        text = text.lower()

        # Remove stop words
        stop_words = set(stopwords.words('english'))
        text = ' '.join([word for word in nltk.word_tokenize(text) if word not in stop_words])

        # Lemmatize the reviews
        lemmatizer = WordNetLemmatizer()
        text = ' '.join([lemmatizer.lemmatize(word) for word in nltk.word_tokenize(text)])

    return text

input_file = 'Stocard_reviews.csv'
output_file = 'Stocard_reviews_preprocessed_reviews.csv'
df = pd.read_csv(input_file)

df['Preprocessed Text'] = df['Review Text'].apply(preprocess_text)

# Output 15 sample preprocessed reviews
sample_preprocessed_reviews = df['Preprocessed Text'].sample(15).tolist()
for i, review in enumerate(sample_preprocessed_reviews, 1):
    print(f"Preprocessed Review {i}: {review}")

df.to_csv(output_file, index=False)
print(f"Preprocessed data saved to '{output_file}'")
# Out:
# Preprocessed Review 1: best card application
# Preprocessed Review 2: outstanding app far
# Preprocessed Review 3: carrying around loyalty card everywhere
# Preprocessed Review 4: handy app dont carry heap card around
# Preprocessed Review 5: easy use
# Preprocessed Review 6: much convenient carrying around store card shame rarely scan need manual entry
# Preprocessed Review 7: put scanner detect barcode phone
# Preprocessed Review 8: convient allows room key
# Preprocessed Review 9: app great carry card around card transferred new phone log account suck reload card
# Preprocessed Review 10: simple easy time space saving love sure cloud backup
# Preprocessed Review 11: brilliant app used lot sold klarna app closed moved card google wallet deleted account deleted app dont want klarna account shame
# Preprocessed Review 12: take photo card enter number create barcodes shop accept image barcode reinstall app today automatic backup restore worked logged installing
# Preprocessed Review 13: good app
# Preprocessed Review 14: genius idea stopped carrying wallet thanks app google pay
# Preprocessed Review 15: nag promos never asked cant find switch annoyance old version ok new one suck
# Preprocessed data saved to 'Stocard_reviews_preprocessed_reviews.csv'

# %% [markdown]
# <h5 style="font-size:1rem;">Key Ring: Loyalty Card App</h5>

# %%
# Function to preprocess text
def preprocess_text(text):
    if isinstance(text, str):
        # Remove punctuations
        text = text.translate(str.maketrans('', '', string.punctuation))

        # Remove special characters and emojis
        text = re.sub(r'[^\w\s]', '', text)

        # Turn numbers into text
        words = []
        for word in nltk.word_tokenize(text):
            if word.isdigit():
                words.append(num2words(word))
            else:
                words.append(word)
        text = ' '.join(words)

        # Remove extra white spaces
        text = ' '.join(text.split())

        # Turn all words into lowercase
        text = text.lower()

        # Remove stop words
        stop_words = set(stopwords.words('english'))
        text = ' '.join([word for word in nltk.word_tokenize(text) if word not in stop_words])

        # Lemmatize the reviews
        lemmatizer = WordNetLemmatizer()
        text = ' '.join([lemmatizer.lemmatize(word) for word in nltk.word_tokenize(text)])

    return text

input_file = 'KeyRing_reviews.csv'
output_file = 'KeyRing_reviews_preprocessed_reviews.csv'
df = pd.read_csv(input_file)

df['Preprocessed Text'] = df['Review Text'].apply(preprocess_text)

# Output 15 sample preprocessed reviews
sample_preprocessed_reviews = df['Preprocessed Text'].sample(15).tolist()
for i, review in enumerate(sample_preprocessed_reviews, 1):
    print(f"Preprocessed Review {i}: {review}")

df.to_csv(output_file, index=False)
print(f"Preprocessed data saved to '{output_file}'")
# Out:
# Preprocessed Review 1:
# Preprocessed Review 2: always count able get back copy reward card
# Preprocessed Review 3: convenient
# Preprocessed Review 4: loved getting rid card much convenient
# Preprocessed Review 5: one useful apps ever created
# Preprocessed Review 6: app work great faded one scanned
# Preprocessed Review 7: great way keep loyalty card
# Preprocessed Review 8: cool idea scanner dont read bar code phone food lion wasnt able make work
# Preprocessed Review 9: cant scan store boo
# Preprocessed Review 10: great app ad android wear support
# Preprocessed Review 11: google wallet loyalty card wont work without internet connection king ring reward
# Preprocessed Review 12: get new one hold money id thats reward card key wallet try agree promise u get coupon even better
# Preprocessed Review 13: love app sooo convenient dont carry around annoying tag
# Preprocessed Review 14: work
# Preprocessed Review 15: great app
# Preprocessed data saved to 'KeyRing_reviews_preprocessed_reviews.csv'

# %% [markdown]
# <h5 style="font-size:1rem;">FidMe Loyalty Cards & Cashback</h5>

# %%
# Function to preprocess text
def preprocess_text(text):
    if isinstance(text, str):
        # Remove punctuations
        text = text.translate(str.maketrans('', '', string.punctuation))

        # Remove special characters and emojis
        text = re.sub(r'[^\w\s]', '', text)

        # Turn numbers into text
        words = []
        for word in nltk.word_tokenize(text):
            if word.isdigit():
                words.append(num2words(word))
            else:
                words.append(word)
        text = ' '.join(words)

        # Remove extra white spaces
        text = ' '.join(text.split())

        # Turn all words into lowercase
        text = text.lower()

        # Remove stop words
        stop_words = set(stopwords.words('english'))
        text = ' '.join([word for word in nltk.word_tokenize(text) if word not in stop_words])

        # Lemmatize the reviews
        lemmatizer = WordNetLemmatizer()
        text = ' '.join([lemmatizer.lemmatize(word) for word in nltk.word_tokenize(text)])

    return text

input_file = 'FidMe_reviews.csv'
output_file = 'FidMe_reviews_preprocessed_reviews.csv'
df = pd.read_csv(input_file)

df['Preprocessed Text'] = df['Review Text'].apply(preprocess_text)

# Output 15 sample preprocessed reviews
sample_preprocessed_reviews = df['Preprocessed Text'].sample(15).tolist()
for i, review in enumerate(sample_preprocessed_reviews, 1):
    print(f"Preprocessed Review {i}: {review}")

df.to_csv(output_file, index=False)
print(f"Preprocessed data saved to '{output_file}'")
# Out:
# Preprocessed Review 1: country listed take time fifteen sec connect server sometimes failed connect say fidme currently trying server please try second barcode generates manual feeding look different loyalty card happens ten loyalty card asks lot permission consume lot battery including gps option customize camera picture specially logo setup option add back card loyalty card info back satisfied customer service trying best help definitely use sometime face problem reason uninstall
# Preprocessed Review 2: cest cool davoir une version française de stocard mais je suis assez déçu que tout tourne autour de grandes chaînes de magasins je pense quil est temp de mettre davantage en avant no commerce de proximité comme lapp fidelatoo le fait très bien avec une app simple rapide et sans pub
# Preprocessed Review 3: here thing even though app design seems made photoshop fails terribly material guideline terribly ugly even probably least ugly app kind keep forced use mobilepocket competitor support pretty much every barcode cant even use ikea bar code
# Preprocessed Review 4: awesome way make wallet thinner
# Preprocessed Review 5: loved app stopped working phone aggregated download new app scan card b
# Preprocessed Review 6: great app love idea
# Preprocessed Review 7: love app
# Preprocessed Review 8: must create account use app used facebook connect setup account popup requesting permission post facebook click cancel popup come back forever way cancel option
# Preprocessed Review 9: perfect idea think develop question time change language setting
# Preprocessed Review 10: app missing rfid card cant sign facebook connect even tho option
# Preprocessed Review 11: excellent
# Preprocessed Review 12: nan
# Preprocessed Review 13: good
# Preprocessed Review 14: wanted start sending unsolicited junk first screen
# Preprocessed Review 15: app bad companion app samsung gear watch isnt really apps moment besides samsung pay however really wanted use goodlife adding card bar code show scanning gym
# Preprocessed data saved to 'FidMe_reviews_preprocessed_reviews.csv'

# %% [markdown]
# <h5 style="font-size:1rem;">Pass2U Wallet - digitize cards</h5>

# %%
# Function to preprocess text
def preprocess_text(text):
    if isinstance(text, str):
        # Remove punctuations
        text = text.translate(str.maketrans('', '', string.punctuation))

        # Remove special characters and emojis
        text = re.sub(r'[^\w\s]', '', text)

        # Turn numbers into text
        words = []
        for word in nltk.word_tokenize(text):
            if word.isdigit():
                words.append(num2words(word))
            else:
                words.append(word)
        text = ' '.join(words)

        # Remove extra white spaces
        text = ' '.join(text.split())

        # Turn all words into lowercase
        text = text.lower()

        # Remove stop words
        stop_words = set(stopwords.words('english'))
        text = ' '.join([word for word in nltk.word_tokenize(text) if word not in stop_words])

        # Lemmatize the reviews
        lemmatizer = WordNetLemmatizer()
        text = ' '.join([lemmatizer.lemmatize(word) for word in nltk.word_tokenize(text)])

    return text

input_file = 'Pass2U_reviews.csv'
output_file = 'Pass2U_reviews_preprocessed_reviews.csv'
df = pd.read_csv(input_file)

df['Preprocessed Text'] = df['Review Text'].apply(preprocess_text)

# Output 15 sample preprocessed reviews
sample_preprocessed_reviews = df['Preprocessed Text'].sample(15).tolist()
for i, review in enumerate(sample_preprocessed_reviews, 1):
    print(f"Preprocessed Review {i}: {review}")

df.to_csv(output_file, index=False)
print(f"Preprocessed data saved to '{output_file}'")
# Out:
# Preprocessed Review 1: great
# Preprocessed Review 2: buena para eventos
# Preprocessed Review 3: track date expected track payment okay app
# Preprocessed Review 4: good handy app loyalty card
# Preprocessed Review 5: nice app developer really listens user
# Preprocessed Review 6: convenient app
# Preprocessed Review 7: convenient app easy store discount card add disturbing great option storing visit card
# Preprocessed Review 8: would great add auto restore option like existing auto backup option
# Preprocessed Review 9: great app easy use
# Preprocessed Review 10: quick access
# Preprocessed Review 11: improve
# Preprocessed Review 12: wouldnt upload pkpass file wouldnt upload photo tried add loyalty card kept upload loop useful
# Preprocessed Review 13: default setting app apparently popup full screen every time unlock phone annoying however alarm went seven get flight physically unable turn due app popping instead even annoying know stupid setting disabled app get one star interfering phone basic behaviour forcing listen painful alarm tone ten time row snooze kicked
# Preprocessed Review 14: unlike another app downloaded one take picture card also barcode scanner app failed pick card app got everyone
# Preprocessed Review 15: amazing app super simple easy use much easier life time board
# Preprocessed data saved to 'Pass2U_reviews_preprocessed_reviews.csv'

# %% [markdown]
# <h3 style="font-size:2rem;">Generate Review Polarity</h3>

# %% [markdown]
# <h5 style="font-size:1rem;">Stocard - Rewards Cards Wallet</h5>

# %%
# !pip install textblob
# Out:
# Requirement already satisfied: textblob in /usr/local/lib/python3.11/dist-packages (0.19.0)
# Requirement already satisfied: nltk>=3.9 in /usr/local/lib/python3.11/dist-packages (from textblob) (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk>=3.9->textblob) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk>=3.9->textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk>=3.9->textblob) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk>=3.9->textblob) (4.67.1)

# %%
from textblob import TextBlob
from IPython.display import display

# %%
# Load preprocessed data from CSV
preprocessed_file = 'Stocard_reviews_preprocessed_reviews.csv'
df = pd.read_csv(preprocessed_file)

# Function to calculate polarity using TextBlob
def calculate_polarity(review):
    blob = TextBlob(review)
    polarity = blob.sentiment.polarity
    return polarity

# Replace missing values in 'Preprocessed Text' column with an empty string
df['Preprocessed Text'].fillna('', inplace=True)

# Calculate polarity
df['Polarity'] = df['Preprocessed Text'].apply(lambda x: calculate_polarity(x) if isinstance(x, str) else 0)

# app's package name
app_package_name = 'de.stocard.stocard'

# Create a DataFrame with the explicit app package name
output_df = pd.DataFrame({
    'App’s package name': [app_package_name] * len(df),
    'Review': df['Preprocessed Text'],
    'Polarity': df['Polarity']
})

# Display at least 250 reviews as required
display(output_df.head(250))
# Out:
# <ipython-input-17-70084fbde1cf>:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Preprocessed Text'].fillna('', inplace=True)
#      App’s package name                                             Review  \
# 0    de.stocard.stocard  understand taking perfectly working app perfec...
# 1    de.stocard.stocard                                     ok sold klarna
# 2    de.stocard.stocard  great app usable anymore moved klarna app acce...
# 3    de.stocard.stocard                                           love app
# 4    de.stocard.stocard  used great connected payment company supercard...
# ..                  ...                                                ...
# 245  de.stocard.stocard  stocard great easy use whats hear youre moving...
# 246  de.stocard.stocard  used best bought klarna disintegrating good lu...
# 247  de.stocard.stocard  best loyalty card app imho used year shut bad ...
# 248  de.stocard.stocard                                       best service
# 249  de.stocard.stocard  love convenience stocard app would given five ...
#
#      Polarity
# 0    0.568182
# 1    0.500000
# 2    0.400000
# 3    0.500000
# 4    0.900000
# ..        ...
# 245 -0.193333
# 246  0.850000
# 247  0.200000
# 248  1.000000
# 249 -0.233333
#
# [250 rows x 3 columns]

# %% [markdown]
# <h5 style="font-size:1rem;">Key Ring: Loyalty Card App</h5>

# %%
# Load preprocessed data from CSV
preprocessed_file = 'KeyRing_reviews_preprocessed_reviews.csv'
df = pd.read_csv(preprocessed_file)

# Function to calculate polarity using TextBlob
def calculate_polarity(review):
    blob = TextBlob(review)
    polarity = blob.sentiment.polarity
    return polarity

# Replace missing values in 'Preprocessed Text' column with an empty string
df['Preprocessed Text'].fillna('', inplace=True)

# Calculate polarity
df['Polarity'] = df['Preprocessed Text'].apply(lambda x: calculate_polarity(x) if isinstance(x, str) else 0)

# app's package name
app_package_name = 'com.froogloid.kring.google.zxing.client.android'

# Create a DataFrame with the explicit app package name
output_df = pd.DataFrame({
    'App’s package name': [app_package_name] * len(df),
    'Review': df['Preprocessed Text'],
    'Polarity': df['Polarity']
})

# Display at least 250 reviews as required
display(output_df.head(250))
# Out:
# <ipython-input-18-68b24e138f4f>:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Preprocessed Text'].fillna('', inplace=True)
#                                   App’s package name  \
# 0    com.froogloid.kring.google.zxing.client.android
# 1    com.froogloid.kring.google.zxing.client.android
# 2    com.froogloid.kring.google.zxing.client.android
# 3    com.froogloid.kring.google.zxing.client.android
# 4    com.froogloid.kring.google.zxing.client.android
# ..                                               ...
# 245  com.froogloid.kring.google.zxing.client.android
# 246  com.froogloid.kring.google.zxing.client.android
# 247  com.froogloid.kring.google.zxing.client.android
# 248  com.froogloid.kring.google.zxing.client.android
# 249  com.froogloid.kring.google.zxing.client.android
#
#                                                 Review  Polarity
# 0                                                great  0.800000
# 1                                                 work  0.000000
# 2    good app would great app could access card via...  0.700000
# 3                              app work like five star  0.000000
# 4    best app ive app year ive never issue app cant...  0.350000
# ..                                                 ...       ...
# 245                                          work fine  0.416667
# 246           ever came app hat youit made life easier  0.000000
# 247  love electronic copy add insurance card covid ...  0.500000
# 248  excellent place track membership loyalty card ...  1.000000
# 249                                        always work  0.000000
#
# [250 rows x 3 columns]

# %% [markdown]
# <h5 style="font-size:1rem;">FidMe Loyalty Cards & Cashback</h5>

# %%
# Load preprocessed data from CSV
preprocessed_file = 'FidMe_reviews_preprocessed_reviews.csv'
df = pd.read_csv(preprocessed_file)

# Function to calculate polarity using TextBlob
def calculate_polarity(review):
    blob = TextBlob(review)
    polarity = blob.sentiment.polarity
    return polarity

# Replace missing values in 'Preprocessed Text' column with an empty string
df['Preprocessed Text'].fillna('', inplace=True)

# Calculate polarity
df['Polarity'] = df['Preprocessed Text'].apply(lambda x: calculate_polarity(x) if isinstance(x, str) else 0)

# app's package name
app_package_name = 'fr.snapp.fidme'

# Create a DataFrame with the explicit app package name
output_df = pd.DataFrame({
    'App’s package name': [app_package_name] * len(df),
    'Review': df['Preprocessed Text'],
    'Polarity': df['Polarity']
})

# Display at least 250 reviews as required
display(output_df.head(250))
# Out:
# <ipython-input-19-89d83db59c1a>:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Preprocessed Text'].fillna('', inplace=True)
#     App’s package name                                             Review  \
# 0       fr.snapp.fidme  import card copy paste number ikea card recogn...
# 1       fr.snapp.fidme  lento leggere coidici barre per importarli e p...
# 2       fr.snapp.fidme  import screenshot sounded like useful feature ...
# 3       fr.snapp.fidme                                         u retailer
# 4       fr.snapp.fidme  ik op zoek naar een vervanger voor stocard omd...
# ..                 ...                                                ...
# 245     fr.snapp.fidme  amazing support ending changing email lost old...
# 246     fr.snapp.fidme  since update cant scan card anymore old one wo...
# 247     fr.snapp.fidme  dont really find coupon useful idea point app ...
# 248     fr.snapp.fidme  great idea tried didnt work card wouldnt scan ...
# 249     fr.snapp.fidme  really appreciate response support team app wi...
#
#      Polarity
# 0    0.000000
# 1    0.000000
# 2   -0.166667
# 3    0.000000
# 4    0.000000
# ..        ...
# 245  0.272727
# 246  0.300000
# 247  0.200000
# 248  0.060000
# 249  0.225000
#
# [250 rows x 3 columns]

# %% [markdown]
# <h5 style="font-size:1rem;">Pass2U Wallet - digitize cards</h5>

# %%
# Load preprocessed data from CSV
preprocessed_file = 'FidMe_reviews_preprocessed_reviews.csv'
df = pd.read_csv(preprocessed_file)

# Function to calculate polarity using TextBlob
def calculate_polarity(review):
    blob = TextBlob(review)
    polarity = blob.sentiment.polarity
    return polarity

# Replace missing values in 'Preprocessed Text' column with an empty string
df['Preprocessed Text'].fillna('', inplace=True)

# Calculate polarity
df['Polarity'] = df['Preprocessed Text'].apply(lambda x: calculate_polarity(x) if isinstance(x, str) else 0)

# app's package name
app_package_name = 'com.passesalliance.wallet'

# Create a DataFrame with the explicit app package name
output_df = pd.DataFrame({
    'App’s package name': [app_package_name] * len(df),
    'Review': df['Preprocessed Text'],
    'Polarity': df['Polarity']
})

# Display at least 250 reviews as required
display(output_df.head(250))
# Out:
# <ipython-input-20-443f511d0d5a>:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Preprocessed Text'].fillna('', inplace=True)
#             App’s package name  \
# 0    com.passesalliance.wallet
# 1    com.passesalliance.wallet
# 2    com.passesalliance.wallet
# 3    com.passesalliance.wallet
# 4    com.passesalliance.wallet
# ..                         ...
# 245  com.passesalliance.wallet
# 246  com.passesalliance.wallet
# 247  com.passesalliance.wallet
# 248  com.passesalliance.wallet
# 249  com.passesalliance.wallet
#
#                                                 Review  Polarity
# 0    import card copy paste number ikea card recogn...  0.000000
# 1    lento leggere coidici barre per importarli e p...  0.000000
# 2    import screenshot sounded like useful feature ... -0.166667
# 3                                           u retailer  0.000000
# 4    ik op zoek naar een vervanger voor stocard omd...  0.000000
# ..                                                 ...       ...
# 245  amazing support ending changing email lost old...  0.272727
# 246  since update cant scan card anymore old one wo...  0.300000
# 247  dont really find coupon useful idea point app ...  0.200000
# 248  great idea tried didnt work card wouldnt scan ...  0.060000
# 249  really appreciate response support team app wi...  0.225000
#
# [250 rows x 3 columns]

# %% [markdown]
# <h3 style="font-size:2rem;">VADER and TextBlob Sentiment Analysis</h3>

# %% [markdown]
# <h5 style="font-size:1rem;">Stocard - Rewards Cards Wallet</h5>

# %%
# !pip install vaderSentiment
# Out:
# Requirement already satisfied: vaderSentiment in /usr/local/lib/python3.11/dist-packages (3.3.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from vaderSentiment) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->vaderSentiment) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->vaderSentiment) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->vaderSentiment) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->vaderSentiment) (2025.1.31)

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from IPython.display import display

# %%
# Load preprocessed data from CSV
preprocessed_file = 'Stocard_reviews_preprocessed_reviews.csv'
df = pd.read_csv(preprocessed_file)

# Initialize VADER sentiment analyzer
sid = SentimentIntensityAnalyzer()

# Function to calculate polarity using VADER
def calculate_polarity_vader(review):
    scores = sid.polarity_scores(review)
    return scores['compound']

# Replace missing values in 'Preprocessed Text' column with an empty string
df['Preprocessed Text'].fillna('', inplace=True)

# Calculate polarity
df['Polarity'] = df['Preprocessed Text'].apply(lambda x: calculate_polarity_vader(x) if isinstance(x, str) else 0)

# app's package name
app_package_name = 'de.stocard.stocard'

# Create a DataFrame with the explicit app package name
output_df_vader = pd.DataFrame({
    'App’s package name': [app_package_name] * len(df),
    'Review': df['Preprocessed Text'],
    'Polarity': df['Polarity']
})

# Limit to 250 reviews as required
output_df_vader = output_df_vader.head(250)

# Display
pd.set_option('display.max_rows', None)
display(output_df_vader)
# Out:
# <ipython-input-23-730fe0fa79dc>:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Preprocessed Text'].fillna('', inplace=True)
#      App’s package name                                             Review  \
# 0    de.stocard.stocard  understand taking perfectly working app perfec...
# 1    de.stocard.stocard                                     ok sold klarna
# 2    de.stocard.stocard  great app usable anymore moved klarna app acce...
# 3    de.stocard.stocard                                           love app
# 4    de.stocard.stocard  used great connected payment company supercard...
# 5    de.stocard.stocard  great app easy place quickly pull reward card ...
# 6    de.stocard.stocard                         good useful used long time
# 7    de.stocard.stocard                                           ease use
# 8    de.stocard.stocard  shame one best loyalty apps destroyed klarna w...
# 9    de.stocard.stocard  used said tin easy set perfect move klarna rui...
# 10   de.stocard.stocard  deceitful deceptive suspicious activity force ...
# 11   de.stocard.stocard  cant access anymore app klarna app seems u use...
# 12   de.stocard.stocard                  loved app discontinued super card
# 13   de.stocard.stocard  lost digital card move klarna try log request ...
# 14   de.stocard.stocard  access card anymore say login klarna work u nu...
# 15   de.stocard.stocard                                           terrible
# 16   de.stocard.stocard  made transition clarna clarna wont log asks u ...
# 17   de.stocard.stocard                         best app save virtual card
# 18   de.stocard.stocard  got acquired klarna dont want client get info ...
# 19   de.stocard.stocard                         purchased klarna uninstall
# 20   de.stocard.stocard  lost loiality card forcing u switch another st...
# 21   de.stocard.stocard  worked south africa klarna doesnt stop using a...
# 22   de.stocard.stocard  lost loyalty cardsthe app migrate klarnato cre...
# 23   de.stocard.stocard  je wordt verplicht deze app te vervangen door ...
# 24   de.stocard.stocard                                          fantastic
# 25   de.stocard.stocard  dont blame owner building app hopefully gettin...
# 26   de.stocard.stocard  move card klarna unaccessible european user ba...
# 27   de.stocard.stocard                                               nice
# 28   de.stocard.stocard  available anymore klarna much worse remove pla...
# 29   de.stocard.stocard  happily using stocard year tell move another a...
# 30   de.stocard.stocard  suddenly migrated another app asking phone num...
# 31   de.stocard.stocard  extremely annoyed perfectly simple working app...
# 32   de.stocard.stocard   didnt let register without north american number
# 33   de.stocard.stocard  worked fine transferred klarna doesnt work fin...
# 34   de.stocard.stocard  used great app following migration klarna lost...
# 35   de.stocard.stocard  forcing move datastealing predatory klarna uni...
# 36   de.stocard.stocard  bad sold changed loved consumer tracking card ...
# 37   de.stocard.stocard                                          lost card
# 38   de.stocard.stocard                                     sold klarna po
# 39   de.stocard.stocard                            supercards stocard used
# 40   de.stocard.stocard                          app good till klarna took
# 41   de.stocard.stocard                                              great
# 42   de.stocard.stocard  good requires phone number klarna thanks unins...
# 43   de.stocard.stocard  year stocard helpful quick digital access cust...
# 44   de.stocard.stocard  used stocard year without worry recently promp...
# 45   de.stocard.stocard  working fine year turned suggest moving anothe...
# 46   de.stocard.stocard  im shocked still marketing stocard belongs kla...
# 47   de.stocard.stocard  pas resent forced move shady loan shark app li...
# 48   de.stocard.stocard      want card back cant recover stupid klarna app
# 49   de.stocard.stocard  bad product move force user switch klarna harm...
# 50   de.stocard.stocard  moved klarna slow ive downloaded supercard app...
# 51   de.stocard.stocard                             zero star moving karma
# 52   de.stocard.stocard  bye bye stocard ich habe die app über jahre ge...
# 53   de.stocard.stocard  loved app one hundred sad klarna took destroye...
# 54   de.stocard.stocard  using app year loved stocard easy use app watc...
# 55   de.stocard.stocard  used excellent merged klarna online shop app a...
# 56   de.stocard.stocard                       wont move klarna uninstalled
# 57   de.stocard.stocard   great app im willing move klarna deleted account
# 58   de.stocard.stocard   forced klarna downgrade every respect imaginable
# 59   de.stocard.stocard                      moved go klarna extremely bad
# 60   de.stocard.stocard  similar recent comment app stopped showing car...
# 61   de.stocard.stocard  use klarna klarna open really slow really bad ...
# 62   de.stocard.stocard  klarna wtaf used able store loyalty card use k...
# 63   de.stocard.stocard  great resource good feature amazing developmen...
# 64   de.stocard.stocard  thirty-one thousand , eight hundred twenty-fiv...
# 65   de.stocard.stocard                                         load phone
# 66   de.stocard.stocard                               great app convenient
# 67   de.stocard.stocard  forced move klarna lost image attached card wa...
# 68   de.stocard.stocard  freaking good klarna bought stocard force use ...
# 69   de.stocard.stocard  sold information without knowledge permission ...
# 70   de.stocard.stocard  two hundred two thousand , five hundred three ...
# 71   de.stocard.stocard  im downgrading rating one app going decommissi...
# 72   de.stocard.stocard  world thinking uninstalled soon told make new ...
# 73   de.stocard.stocard  absolutely annoyingkeeps sending advert hard s...
# 74   de.stocard.stocard                       great card one spot easy use
# 75   de.stocard.stocard                                           adverage
# 76   de.stocard.stocard  van five naar one ster klarna komt nooit op mi...
# 77   de.stocard.stocard  made change stocard klarna wont let log dont e...
# 78   de.stocard.stocard  disappointed unauthorized transfer reward card...
# 79   de.stocard.stocard                                          great app
# 80   de.stocard.stocard  klarna im stuck need north american phone numb...
# 81   de.stocard.stocard                         app sold klarna im leaving
# 82   de.stocard.stocard  app longer work force go another app klarna sl...
# 83   de.stocard.stocard  ik zie dat functionaliteit gaat naar klarna ik...
# 84   de.stocard.stocard  mist de optie om het tabblad aanbiedingen uit ...
# 85   de.stocard.stocard  bought klarna app buying app card buying kind ...
# 86   de.stocard.stocard  login kalma dont accept french number want acc...
# 87   de.stocard.stocard  great app sad see go zero interest klarna account
# 88   de.stocard.stocard  jammer overgenomen door klarna dus ik ben er w...
# 89   de.stocard.stocard  nie mogę migrować konta ponieważ tylko dla ame...
# 90   de.stocard.stocard                      ok changed app app dont touch
# 91   de.stocard.stocard  asked update lost half card even trying retrie...
# 92   de.stocard.stocard        disappointed forced onto klarna app deleted
# 93   de.stocard.stocard  everything forcefully moved klarna install kee...
# 94   de.stocard.stocard  used app year brilliant want move klarna movin...
# 95   de.stocard.stocard  best loyalty stocking app card one roof easy u...
# 96   de.stocard.stocard                                used goodnow klarna
# 97   de.stocard.stocard  obligated move klarna app perfect klarna offer...
# 98   de.stocard.stocard          perfect year dont want klarna uninstalled
# 99   de.stocard.stocard   excellent facility store shop card android phone
# 100  de.stocard.stocard  stocard moved klarna downhill loading slow con...
# 101  de.stocard.stocard    good app letting open rather use stocard klarna
# 102  de.stocard.stocard                                               good
# 103  de.stocard.stocard  easy useful app intrusive ad notification turn...
# 104  de.stocard.stocard  remove insurance transitioning away app reinst...
# 105  de.stocard.stocard  app sold klarna service earning big money tric...
# 106  de.stocard.stocard                                         convenient
# 107  de.stocard.stocard  excellent free wallet carrying whole bunch car...
# 108  de.stocard.stocard       best app since owned klara app doesnt widget
# 109  de.stocard.stocard  stocard brilliant 5stars sold klarna dont know...
# 110  de.stocard.stocard  lapplication à été migrée vers une autre et je...
# 111  de.stocard.stocard  great since sing klama much first phone app st...
# 112  de.stocard.stocard  amazing card manager app ive used year sad tak...
# 113  de.stocard.stocard                           klarna ui disappointment
# 114  de.stocard.stocard                   love love longer issue dont card
# 115  de.stocard.stocard                                   use often ok use
# 116  de.stocard.stocard  nice app forced pas klarna dont want sign anyo...
# 117  de.stocard.stocard          moving anywhere need saving barcodes card
# 118  de.stocard.stocard  need another app klarna open app good app basi...
# 119  de.stocard.stocard  promoted migrate klarna first thing asked phon...
# 120  de.stocard.stocard  přechod na klarma nebo jak se ten bazdmeg jmen...
# 121  de.stocard.stocard                           moving klarna app ruined
# 122  de.stocard.stocard            killed klarna rip another good app gone
# 123  de.stocard.stocard  lapplication naffiche plus le carte elle deman...
# 124  de.stocard.stocard  easy access card even one made make easy info ...
# 125  de.stocard.stocard  app pretty much useless selling klarna made wi...
# 126  de.stocard.stocard                                              great
# 127  de.stocard.stocard  best loyalty card app card stored phone organi...
# 128  de.stocard.stocard  quite id manage shift app klarn stuck sainsbur...
# 129  de.stocard.stocard  stocard eaten bij klarna suppose picture put c...
# 130  de.stocard.stocard                                               good
# 131  de.stocard.stocard               silly klarna thing waste review good
# 132  de.stocard.stocard  great app recently today let wanted use saved ...
# 133  de.stocard.stocard  win iphone garbage promotion cad longer access...
# 134  de.stocard.stocard                                     sad see app go
# 135  de.stocard.stocard  good ive let store register change find anothe...
# 136  de.stocard.stocard      using app age telling use klana app dont like
# 137  de.stocard.stocard  move klarna huge mistake good job selling new ...
# 138  de.stocard.stocard  loved stocard sad replaced klarna hate klarna ...
# 139  de.stocard.stocard  love app apparently changing klarna encourage ...
# 140  de.stocard.stocard  uninstalled also klarna happy financial link p...
# 141  de.stocard.stocard  know need use klarna whats wrong still using s...
# 142  de.stocard.stocard  essentially forced install credit app doubt tr...
# 143  de.stocard.stocard  best app ever fantastic widget integration bac...
# 144  de.stocard.stocard  disappointed u sold karma want number email in...
# 145  de.stocard.stocard     know happend apps say account exist definitely
# 146  de.stocard.stocard      forced update new klarna app complete rubbish
# 147  de.stocard.stocard      thank much switching klarna available country
# 148  de.stocard.stocard           loved stocard klarna mess ditched pronto
# 149  de.stocard.stocard  used love app cant even go trough text verific...
# 150  de.stocard.stocard  removing storcard used year since klarna ridic...
# 151  de.stocard.stocard  please let u keep app best app easy use offlin...
# 152  de.stocard.stocard          convience instead looking purse use phone
# 153  de.stocard.stocard  originally installed app feature add particula...
# 154  de.stocard.stocard  longer working directed download klarna app bi...
# 155  de.stocard.stocard                transfer card klarna came stupidity
# 156  de.stocard.stocard                                    rip good lasted
# 157  de.stocard.stocard  id using app year klarna took gave shot hate s...
# 158  de.stocard.stocard  non ho intenzione di spostarmi su klarna solo ...
# 159  de.stocard.stocard                            pain backside wont turn
# 160  de.stocard.stocard                            stocard killed run away
# 161  de.stocard.stocard                 loose card possible login facebook
# 162  de.stocard.stocard                                    best card saver
# 163  de.stocard.stocard  five star sold slower bloated app uninstalled ...
# 164  de.stocard.stocard                              changed app new login
# 165  de.stocard.stocard  great got new phone unfortunately wont let res...
# 166  de.stocard.stocard          perfect acquired klarna use google wallet
# 167  de.stocard.stocard                                             useful
# 168  de.stocard.stocard                  klarna let use stocard satisfying
# 169  de.stocard.stocard                                        sold klarna
# 170  de.stocard.stocard  tutte le carte unica app senza dover scaricare...
# 171  de.stocard.stocard                   stocard great app klarna rubbish
# 172  de.stocard.stocard  edit finding another app replaced klarna enjoy...
# 173  de.stocard.stocard  used great app moved klarna became terrible ca...
# 174  de.stocard.stocard  klarna takeover app trash dont sign klarna pri...
# 175  de.stocard.stocard                           convenient easy use love
# 176  de.stocard.stocard                          stocard moving klarna bye
# 177  de.stocard.stocard                   absolutely help app link website
# 178  de.stocard.stocard  using app year registration klarna disappointe...
# 179  de.stocard.stocard  love using app wallet store card using store w...
# 180  de.stocard.stocard           doesnt work confirmation code never come
# 181  de.stocard.stocard  love help alot especially dont want carry card...
# 182  de.stocard.stocard                      terrible app klarna new owner
# 183  de.stocard.stocard                                    rated five star
# 184  de.stocard.stocard  stocard sold klarna useful program yet ive mov...
# 185  de.stocard.stocard  easy use save missing swiping usual loyalty ca...
# 186  de.stocard.stocard  want delete halo fresh canti want app phone em...
# 187  de.stocard.stocard  since moved klarna seems slow seems require in...
# 188  de.stocard.stocard                                        rip stocard
# 189  de.stocard.stocard  update app force migrate data another app down...
# 190  de.stocard.stocard  ive using stocard app last year glitch work ex...
# 191  de.stocard.stocard  way ruin app klarna uninstalling today getting...
# 192  de.stocard.stocard  work well card barcode else need type number m...
# 193  de.stocard.stocard  great go app longer work watch wearos since kl...
# 194  de.stocard.stocard  fantastic useful app worked internet connectio...
# 195  de.stocard.stocard  really enjoy app minimal ad really upset going...
# 196  de.stocard.stocard  stocard brilliant storing using loyalty card a...
# 197  de.stocard.stocard  goodbye great app thats taken klarna thanks ap...
# 198  de.stocard.stocard     totally free advertising popups annoying thing
# 199  de.stocard.stocard                many advertising sm sent interested
# 200  de.stocard.stocard                                doesnt work anymore
# 201  de.stocard.stocard  sold klarna horrible liked stocard klarna wret...
# 202  de.stocard.stocard  stocard joined force klarna already two thousa...
# 203  de.stocard.stocard  stocard great app keep loyalty card shame disc...
# 204  de.stocard.stocard                                               good
# 205  de.stocard.stocard  lowered score five see benefit calltoaction mi...
# 206  de.stocard.stocard                      convenient way card one place
# 207  de.stocard.stocard  moved catima could screenshot barcodes share c...
# 208  de.stocard.stocard  great app good lasted moving klarna request mu...
# 209  de.stocard.stocard  seventy-two thousand , one hundred sixteen wor...
# 210  de.stocard.stocard  gone klarna doesnt work fast irritation cash desk
# 211  de.stocard.stocard  nice app moved klarna dont want fortunately ni...
# 212  de.stocard.stocard  loved app year recommended everyone painful sl...
# 213  de.stocard.stocard  unfortunately app moving klarna fifty-five use...
# 214  de.stocard.stocard  good lasted great app bought predatory company...
# 215  de.stocard.stocard  excellent standard klarna upcoming replacement...
# 216  de.stocard.stocard  used good taken another app sell data third party
# 217  de.stocard.stocard  since bought klarna ive deleted dont want make...
# 218  de.stocard.stocard  cant login anymore old account blocked old acc...
# 219  de.stocard.stocard    stored card made another app called klarna good
# 220  de.stocard.stocard  real shame stocard wont exist tried force onto...
# 221  de.stocard.stocard  great app love please dont get rid move anothe...
# 222  de.stocard.stocard                                                yep
# 223  de.stocard.stocard                         changed klarna finance app
# 224  de.stocard.stocard  farewell stocard missed dont want port code pa...
# 225  de.stocard.stocard  stocard abandoned user moved klarna dont feel ...
# 226  de.stocard.stocard  pourquoi ne pa avoir prévenu que cette mise à ...
# 227  de.stocard.stocard  used best app card wallet capable one thing ri...
# 228  de.stocard.stocard  sadly bought klarna dont want looking another ...
# 229  de.stocard.stocard  useful interested payment app since klarna bou...
# 230  de.stocard.stocard  updated new app entirely thank goodness old ph...
# 231  de.stocard.stocard  migrate klarna happy stocard easy efficient es...
# 232  de.stocard.stocard  used app time reason everyone say longer going...
# 233  de.stocard.stocard  good forced move klarna oblige register phone ...
# 234  de.stocard.stocard  happily used year moving away dont like taken ...
# 235  de.stocard.stocard  al mijn stocards zijn verdwenen en ik krijg ze...
# 236  de.stocard.stocard  ich war immer zufrieden jetzt musste ich aufgr...
# 237  de.stocard.stocard                  lost loyalty card klarna takeover
# 238  de.stocard.stocard  used excellent card klarna awful slow unrespon...
# 239  de.stocard.stocard  used stocard quite time dont want migrate klar...
# 240  de.stocard.stocard  forced migration new app requires account vali...
# 241  de.stocard.stocard  great app aquisition find incredibly frustrati...
# 242  de.stocard.stocard                     silly move new app bye stocard
# 243  de.stocard.stocard  wonderful app many many year unfortunately mig...
# 244  de.stocard.stocard  go stocard klarna huge shame simple easy use a...
# 245  de.stocard.stocard  stocard great easy use whats hear youre moving...
# 246  de.stocard.stocard  used best bought klarna disintegrating good lu...
# 247  de.stocard.stocard  best loyalty card app imho used year shut bad ...
# 248  de.stocard.stocard                                       best service
# 249  de.stocard.stocard  love convenience stocard app would given five ...
#
#      Polarity
# 0      0.9062
# 1      0.2960
# 2      0.7906
# 3      0.6369
# 4      0.8316
# 5      0.8074
# 6      0.7003
# 7      0.3612
# 8      0.0936
# 9      0.9217
# 10    -0.8807
# 11     0.0000
# 12     0.8316
# 13    -0.2500
# 14    -0.4215
# 15    -0.4767
# 16    -0.3182
# 17     0.8126
# 18    -0.0572
# 19     0.0000
# 20    -0.3818
# 21     0.2235
# 22     0.5106
# 23     0.0000
# 24     0.5574
# 25     0.7674
# 26    -0.3182
# 27     0.4215
# 28    -0.1779
# 29     0.5994
# 30     0.4019
# 31     0.1742
# 32    -0.0572
# 33    -0.3595
# 34     0.8689
# 35     0.2944
# 36     0.1027
# 37    -0.3182
# 38    -0.5574
# 39     0.0000
# 40     0.4404
# 41     0.6249
# 42     0.7269
# 43     0.6249
# 44     0.1984
# 45     0.7774
# 46    -0.5267
# 47    -0.3818
# 48     0.4724
# 49     0.4404
# 50     0.4404
# 51     0.0000
# 52    -0.7506
# 53    -0.4404
# 54     0.9100
# 55     0.8020
# 56     0.0000
# 57     0.6249
# 58     0.0258
# 59    -0.5849
# 60    -0.2263
# 61    -0.6300
# 62     0.8176
# 63     0.9545
# 64    -0.1119
# 65     0.0000
# 66     0.6249
# 67    -0.6486
# 68     0.0258
# 69    -0.5719
# 70     0.9081
# 71     0.5526
# 72    -0.3182
# 73    -0.4767
# 74     0.7906
# 75     0.0000
# 76     0.0000
# 77    -0.3658
# 78     0.5859
# 79     0.6249
# 80    -0.6249
# 81     0.0000
# 82     0.0000
# 83     0.0000
# 84     0.0000
# 85     0.5267
# 86    -0.2746
# 87     0.6124
# 88     0.0000
# 89    -0.5719
# 90     0.2960
# 91    -0.3182
# 92    -0.7269
# 93    -0.6808
# 94     0.0258
# 95     0.8910
# 96     0.0000
# 97     0.5719
# 98     0.5389
# 99     0.5719
# 100   -0.1027
# 101    0.4404
# 102    0.4404
# 103    0.7003
# 104    0.1531
# 105   -0.3400
# 106    0.0000
# 107    0.9153
# 108    0.6369
# 109   -0.5106
# 110    0.0000
# 111    0.7096
# 112    0.6705
# 113   -0.5106
# 114    0.8555
# 115    0.2960
# 116   -0.1083
# 117    0.0000
# 118    0.4404
# 119    0.0772
# 120    0.0000
# 121   -0.4767
# 122   -0.3818
# 123    0.0000
# 124    0.9217
# 125    0.1027
# 126    0.6249
# 127    0.8519
# 128   -0.2500
# 129    0.0000
# 130    0.4404
# 131    0.0516
# 132    0.8225
# 133    0.5859
# 134   -0.4767
# 135    0.4404
# 136   -0.2755
# 137   -0.0258
# 138   -0.0772
# 139    0.8779
# 140    0.3182
# 141   -0.3612
# 142    0.1531
# 143    0.9393
# 144   -0.3612
# 145    0.4019
# 146   -0.4588
# 147    0.3612
# 148    0.3400
# 149    0.6369
# 150   -0.7351
# 151    0.8360
# 152    0.0000
# 153    0.0000
# 154    0.8625
# 155   -0.4404
# 156    0.4404
# 157   -0.1027
# 158    0.0000
# 159   -0.5106
# 160   -0.6705
# 161   -0.3182
# 162    0.6369
# 163    0.0000
# 164    0.0000
# 165    0.5736
# 166    0.5719
# 167    0.4404
# 168    0.4588
# 169    0.0000
# 170    0.0000
# 171    0.6249
# 172    0.7096
# 173    0.6369
# 174   -0.4019
# 175    0.7964
# 176    0.0000
# 177    0.4576
# 178   -0.4767
# 179    0.7549
# 180    0.0000
# 181    0.9001
# 182   -0.4767
# 183    0.0000
# 184    0.4404
# 185    0.8126
# 186    0.4404
# 187   -0.4404
# 188    0.0000
# 189    0.4939
# 190   -0.6369
# 191   -0.5859
# 192    0.7783
# 193    0.8225
# 194    0.8126
# 195    0.4902
# 196    0.8885
# 197    0.7906
# 198    0.2247
# 199    0.4019
# 200    0.0000
# 201   -0.1779
# 202    0.4287
# 203    0.8910
# 204    0.4404
# 205    0.4215
# 206    0.0000
# 207    0.8519
# 208    0.7906
# 209    0.5719
# 210    0.4023
# 211    0.9418
# 212   -0.5678
# 213   -0.6369
# 214    0.8834
# 215    0.2023
# 216    0.6808
# 217    0.7564
# 218    0.0772
# 219    0.4404
# 220    0.5106
# 221    0.9360
# 222    0.2960
# 223    0.0000
# 224   -0.1833
# 225   -0.4218
# 226    0.0000
# 227    0.6124
# 228   -0.1833
# 229    0.6808
# 230    0.7245
# 231    0.9349
# 232    0.8239
# 233    0.0516
# 234    0.3591
# 235    0.0000
# 236   -0.9136
# 237    0.2960
# 238    0.1779
# 239    0.6922
# 240   -0.4019
# 241    0.7096
# 242    0.0258
# 243   -0.2960
# 244    0.4404
# 245    0.4860
# 246    0.8779
# 247    0.7430
# 248    0.6369
# 249    0.3612

# %% [markdown]
# <h5 style="font-size:1rem;">Key Ring: Loyalty Card App</h5>

# %%
# Load preprocessed data from CSV
preprocessed_file = 'KeyRing_reviews_preprocessed_reviews.csv'
df = pd.read_csv(preprocessed_file)

# Initialize VADER sentiment analyzer
sid = SentimentIntensityAnalyzer()

# Function to calculate polarity using VADER
def calculate_polarity_vader(review):
    scores = sid.polarity_scores(review)
    return scores['compound']

# Replace missing values in 'Preprocessed Text' column with an empty string
df['Preprocessed Text'].fillna('', inplace=True)

# Calculate polarity
df['Polarity'] = df['Preprocessed Text'].apply(lambda x: calculate_polarity_vader(x) if isinstance(x, str) else 0)

# app's package name
app_package_name = 'com.froogloid.kring.google.zxing.client.android'

# Create a DataFrame with the explicit app package name
output_df_vader = pd.DataFrame({
    'App’s package name': [app_package_name] * len(df),
    'Review': df['Preprocessed Text'],
    'Polarity': df['Polarity']
})

# Limit to 250 reviews as required
output_df_vader = output_df_vader.head(250)

# Display
pd.set_option('display.max_rows', None)
display(output_df_vader)
# Out:
# <ipython-input-24-c9f435d24e66>:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Preprocessed Text'].fillna('', inplace=True)
#                                   App’s package name  \
# 0    com.froogloid.kring.google.zxing.client.android
# 1    com.froogloid.kring.google.zxing.client.android
# 2    com.froogloid.kring.google.zxing.client.android
# 3    com.froogloid.kring.google.zxing.client.android
# 4    com.froogloid.kring.google.zxing.client.android
# 5    com.froogloid.kring.google.zxing.client.android
# 6    com.froogloid.kring.google.zxing.client.android
# 7    com.froogloid.kring.google.zxing.client.android
# 8    com.froogloid.kring.google.zxing.client.android
# 9    com.froogloid.kring.google.zxing.client.android
# 10   com.froogloid.kring.google.zxing.client.android
# 11   com.froogloid.kring.google.zxing.client.android
# 12   com.froogloid.kring.google.zxing.client.android
# 13   com.froogloid.kring.google.zxing.client.android
# 14   com.froogloid.kring.google.zxing.client.android
# 15   com.froogloid.kring.google.zxing.client.android
# 16   com.froogloid.kring.google.zxing.client.android
# 17   com.froogloid.kring.google.zxing.client.android
# 18   com.froogloid.kring.google.zxing.client.android
# 19   com.froogloid.kring.google.zxing.client.android
# 20   com.froogloid.kring.google.zxing.client.android
# 21   com.froogloid.kring.google.zxing.client.android
# 22   com.froogloid.kring.google.zxing.client.android
# 23   com.froogloid.kring.google.zxing.client.android
# 24   com.froogloid.kring.google.zxing.client.android
# 25   com.froogloid.kring.google.zxing.client.android
# 26   com.froogloid.kring.google.zxing.client.android
# 27   com.froogloid.kring.google.zxing.client.android
# 28   com.froogloid.kring.google.zxing.client.android
# 29   com.froogloid.kring.google.zxing.client.android
# 30   com.froogloid.kring.google.zxing.client.android
# 31   com.froogloid.kring.google.zxing.client.android
# 32   com.froogloid.kring.google.zxing.client.android
# 33   com.froogloid.kring.google.zxing.client.android
# 34   com.froogloid.kring.google.zxing.client.android
# 35   com.froogloid.kring.google.zxing.client.android
# 36   com.froogloid.kring.google.zxing.client.android
# 37   com.froogloid.kring.google.zxing.client.android
# 38   com.froogloid.kring.google.zxing.client.android
# 39   com.froogloid.kring.google.zxing.client.android
# 40   com.froogloid.kring.google.zxing.client.android
# 41   com.froogloid.kring.google.zxing.client.android
# 42   com.froogloid.kring.google.zxing.client.android
# 43   com.froogloid.kring.google.zxing.client.android
# 44   com.froogloid.kring.google.zxing.client.android
# 45   com.froogloid.kring.google.zxing.client.android
# 46   com.froogloid.kring.google.zxing.client.android
# 47   com.froogloid.kring.google.zxing.client.android
# 48   com.froogloid.kring.google.zxing.client.android
# 49   com.froogloid.kring.google.zxing.client.android
# 50   com.froogloid.kring.google.zxing.client.android
# 51   com.froogloid.kring.google.zxing.client.android
# 52   com.froogloid.kring.google.zxing.client.android
# 53   com.froogloid.kring.google.zxing.client.android
# 54   com.froogloid.kring.google.zxing.client.android
# 55   com.froogloid.kring.google.zxing.client.android
# 56   com.froogloid.kring.google.zxing.client.android
# 57   com.froogloid.kring.google.zxing.client.android
# 58   com.froogloid.kring.google.zxing.client.android
# 59   com.froogloid.kring.google.zxing.client.android
# 60   com.froogloid.kring.google.zxing.client.android
# 61   com.froogloid.kring.google.zxing.client.android
# 62   com.froogloid.kring.google.zxing.client.android
# 63   com.froogloid.kring.google.zxing.client.android
# 64   com.froogloid.kring.google.zxing.client.android
# 65   com.froogloid.kring.google.zxing.client.android
# 66   com.froogloid.kring.google.zxing.client.android
# 67   com.froogloid.kring.google.zxing.client.android
# 68   com.froogloid.kring.google.zxing.client.android
# 69   com.froogloid.kring.google.zxing.client.android
# 70   com.froogloid.kring.google.zxing.client.android
# 71   com.froogloid.kring.google.zxing.client.android
# 72   com.froogloid.kring.google.zxing.client.android
# 73   com.froogloid.kring.google.zxing.client.android
# 74   com.froogloid.kring.google.zxing.client.android
# 75   com.froogloid.kring.google.zxing.client.android
# 76   com.froogloid.kring.google.zxing.client.android
# 77   com.froogloid.kring.google.zxing.client.android
# 78   com.froogloid.kring.google.zxing.client.android
# 79   com.froogloid.kring.google.zxing.client.android
# 80   com.froogloid.kring.google.zxing.client.android
# 81   com.froogloid.kring.google.zxing.client.android
# 82   com.froogloid.kring.google.zxing.client.android
# 83   com.froogloid.kring.google.zxing.client.android
# 84   com.froogloid.kring.google.zxing.client.android
# 85   com.froogloid.kring.google.zxing.client.android
# 86   com.froogloid.kring.google.zxing.client.android
# 87   com.froogloid.kring.google.zxing.client.android
# 88   com.froogloid.kring.google.zxing.client.android
# 89   com.froogloid.kring.google.zxing.client.android
# 90   com.froogloid.kring.google.zxing.client.android
# 91   com.froogloid.kring.google.zxing.client.android
# 92   com.froogloid.kring.google.zxing.client.android
# 93   com.froogloid.kring.google.zxing.client.android
# 94   com.froogloid.kring.google.zxing.client.android
# 95   com.froogloid.kring.google.zxing.client.android
# 96   com.froogloid.kring.google.zxing.client.android
# 97   com.froogloid.kring.google.zxing.client.android
# 98   com.froogloid.kring.google.zxing.client.android
# 99   com.froogloid.kring.google.zxing.client.android
# 100  com.froogloid.kring.google.zxing.client.android
# 101  com.froogloid.kring.google.zxing.client.android
# 102  com.froogloid.kring.google.zxing.client.android
# 103  com.froogloid.kring.google.zxing.client.android
# 104  com.froogloid.kring.google.zxing.client.android
# 105  com.froogloid.kring.google.zxing.client.android
# 106  com.froogloid.kring.google.zxing.client.android
# 107  com.froogloid.kring.google.zxing.client.android
# 108  com.froogloid.kring.google.zxing.client.android
# 109  com.froogloid.kring.google.zxing.client.android
# 110  com.froogloid.kring.google.zxing.client.android
# 111  com.froogloid.kring.google.zxing.client.android
# 112  com.froogloid.kring.google.zxing.client.android
# 113  com.froogloid.kring.google.zxing.client.android
# 114  com.froogloid.kring.google.zxing.client.android
# 115  com.froogloid.kring.google.zxing.client.android
# 116  com.froogloid.kring.google.zxing.client.android
# 117  com.froogloid.kring.google.zxing.client.android
# 118  com.froogloid.kring.google.zxing.client.android
# 119  com.froogloid.kring.google.zxing.client.android
# 120  com.froogloid.kring.google.zxing.client.android
# 121  com.froogloid.kring.google.zxing.client.android
# 122  com.froogloid.kring.google.zxing.client.android
# 123  com.froogloid.kring.google.zxing.client.android
# 124  com.froogloid.kring.google.zxing.client.android
# 125  com.froogloid.kring.google.zxing.client.android
# 126  com.froogloid.kring.google.zxing.client.android
# 127  com.froogloid.kring.google.zxing.client.android
# 128  com.froogloid.kring.google.zxing.client.android
# 129  com.froogloid.kring.google.zxing.client.android
# 130  com.froogloid.kring.google.zxing.client.android
# 131  com.froogloid.kring.google.zxing.client.android
# 132  com.froogloid.kring.google.zxing.client.android
# 133  com.froogloid.kring.google.zxing.client.android
# 134  com.froogloid.kring.google.zxing.client.android
# 135  com.froogloid.kring.google.zxing.client.android
# 136  com.froogloid.kring.google.zxing.client.android
# 137  com.froogloid.kring.google.zxing.client.android
# 138  com.froogloid.kring.google.zxing.client.android
# 139  com.froogloid.kring.google.zxing.client.android
# 140  com.froogloid.kring.google.zxing.client.android
# 141  com.froogloid.kring.google.zxing.client.android
# 142  com.froogloid.kring.google.zxing.client.android
# 143  com.froogloid.kring.google.zxing.client.android
# 144  com.froogloid.kring.google.zxing.client.android
# 145  com.froogloid.kring.google.zxing.client.android
# 146  com.froogloid.kring.google.zxing.client.android
# 147  com.froogloid.kring.google.zxing.client.android
# 148  com.froogloid.kring.google.zxing.client.android
# 149  com.froogloid.kring.google.zxing.client.android
# 150  com.froogloid.kring.google.zxing.client.android
# 151  com.froogloid.kring.google.zxing.client.android
# 152  com.froogloid.kring.google.zxing.client.android
# 153  com.froogloid.kring.google.zxing.client.android
# 154  com.froogloid.kring.google.zxing.client.android
# 155  com.froogloid.kring.google.zxing.client.android
# 156  com.froogloid.kring.google.zxing.client.android
# 157  com.froogloid.kring.google.zxing.client.android
# 158  com.froogloid.kring.google.zxing.client.android
# 159  com.froogloid.kring.google.zxing.client.android
# 160  com.froogloid.kring.google.zxing.client.android
# 161  com.froogloid.kring.google.zxing.client.android
# 162  com.froogloid.kring.google.zxing.client.android
# 163  com.froogloid.kring.google.zxing.client.android
# 164  com.froogloid.kring.google.zxing.client.android
# 165  com.froogloid.kring.google.zxing.client.android
# 166  com.froogloid.kring.google.zxing.client.android
# 167  com.froogloid.kring.google.zxing.client.android
# 168  com.froogloid.kring.google.zxing.client.android
# 169  com.froogloid.kring.google.zxing.client.android
# 170  com.froogloid.kring.google.zxing.client.android
# 171  com.froogloid.kring.google.zxing.client.android
# 172  com.froogloid.kring.google.zxing.client.android
# 173  com.froogloid.kring.google.zxing.client.android
# 174  com.froogloid.kring.google.zxing.client.android
# 175  com.froogloid.kring.google.zxing.client.android
# 176  com.froogloid.kring.google.zxing.client.android
# 177  com.froogloid.kring.google.zxing.client.android
# 178  com.froogloid.kring.google.zxing.client.android
# 179  com.froogloid.kring.google.zxing.client.android
# 180  com.froogloid.kring.google.zxing.client.android
# 181  com.froogloid.kring.google.zxing.client.android
# 182  com.froogloid.kring.google.zxing.client.android
# 183  com.froogloid.kring.google.zxing.client.android
# 184  com.froogloid.kring.google.zxing.client.android
# 185  com.froogloid.kring.google.zxing.client.android
# 186  com.froogloid.kring.google.zxing.client.android
# 187  com.froogloid.kring.google.zxing.client.android
# 188  com.froogloid.kring.google.zxing.client.android
# 189  com.froogloid.kring.google.zxing.client.android
# 190  com.froogloid.kring.google.zxing.client.android
# 191  com.froogloid.kring.google.zxing.client.android
# 192  com.froogloid.kring.google.zxing.client.android
# 193  com.froogloid.kring.google.zxing.client.android
# 194  com.froogloid.kring.google.zxing.client.android
# 195  com.froogloid.kring.google.zxing.client.android
# 196  com.froogloid.kring.google.zxing.client.android
# 197  com.froogloid.kring.google.zxing.client.android
# 198  com.froogloid.kring.google.zxing.client.android
# 199  com.froogloid.kring.google.zxing.client.android
# 200  com.froogloid.kring.google.zxing.client.android
# 201  com.froogloid.kring.google.zxing.client.android
# 202  com.froogloid.kring.google.zxing.client.android
# 203  com.froogloid.kring.google.zxing.client.android
# 204  com.froogloid.kring.google.zxing.client.android
# 205  com.froogloid.kring.google.zxing.client.android
# 206  com.froogloid.kring.google.zxing.client.android
# 207  com.froogloid.kring.google.zxing.client.android
# 208  com.froogloid.kring.google.zxing.client.android
# 209  com.froogloid.kring.google.zxing.client.android
# 210  com.froogloid.kring.google.zxing.client.android
# 211  com.froogloid.kring.google.zxing.client.android
# 212  com.froogloid.kring.google.zxing.client.android
# 213  com.froogloid.kring.google.zxing.client.android
# 214  com.froogloid.kring.google.zxing.client.android
# 215  com.froogloid.kring.google.zxing.client.android
# 216  com.froogloid.kring.google.zxing.client.android
# 217  com.froogloid.kring.google.zxing.client.android
# 218  com.froogloid.kring.google.zxing.client.android
# 219  com.froogloid.kring.google.zxing.client.android
# 220  com.froogloid.kring.google.zxing.client.android
# 221  com.froogloid.kring.google.zxing.client.android
# 222  com.froogloid.kring.google.zxing.client.android
# 223  com.froogloid.kring.google.zxing.client.android
# 224  com.froogloid.kring.google.zxing.client.android
# 225  com.froogloid.kring.google.zxing.client.android
# 226  com.froogloid.kring.google.zxing.client.android
# 227  com.froogloid.kring.google.zxing.client.android
# 228  com.froogloid.kring.google.zxing.client.android
# 229  com.froogloid.kring.google.zxing.client.android
# 230  com.froogloid.kring.google.zxing.client.android
# 231  com.froogloid.kring.google.zxing.client.android
# 232  com.froogloid.kring.google.zxing.client.android
# 233  com.froogloid.kring.google.zxing.client.android
# 234  com.froogloid.kring.google.zxing.client.android
# 235  com.froogloid.kring.google.zxing.client.android
# 236  com.froogloid.kring.google.zxing.client.android
# 237  com.froogloid.kring.google.zxing.client.android
# 238  com.froogloid.kring.google.zxing.client.android
# 239  com.froogloid.kring.google.zxing.client.android
# 240  com.froogloid.kring.google.zxing.client.android
# 241  com.froogloid.kring.google.zxing.client.android
# 242  com.froogloid.kring.google.zxing.client.android
# 243  com.froogloid.kring.google.zxing.client.android
# 244  com.froogloid.kring.google.zxing.client.android
# 245  com.froogloid.kring.google.zxing.client.android
# 246  com.froogloid.kring.google.zxing.client.android
# 247  com.froogloid.kring.google.zxing.client.android
# 248  com.froogloid.kring.google.zxing.client.android
# 249  com.froogloid.kring.google.zxing.client.android
#
#                                                 Review  Polarity
# 0                                                great    0.6249
# 1                                                 work    0.0000
# 2    good app would great app could access card via...    0.8957
# 3                              app work like five star    0.3612
# 4    best app ive app year ive never issue app cant...    0.8658
# 5                            love new key chain wallet    0.6369
# 6                                                great    0.6249
# 7                                    simple easy claim    0.4404
# 8    used app long time far best app market ease us...    0.7906
# 9    ive app long time seemed great however get lot...    0.4767
# 10                                          convenient    0.0000
# 11   like others already stated previosly awesome a...    0.9528
# 12   user year use five star since went app website...    0.7878
# 13         great app helpful wish didnt log every time    0.8625
# 14                                            love app    0.6369
# 15                                         awesome app    0.6249
# 16                                           work well    0.2732
# 17      love carry physical card fact store photo card    0.6369
# 18                                            easy use    0.4404
# 19     easy use love create shopping list family share    0.8860
# 20                                   handy time saving    0.0000
# 21   youll never remember customer loyalty card app...    0.3071
# 22                                      convenient use    0.0000
# 23             always use google wallet samsung wallet    0.0000
# 24   doesnt seem supported anymore help support go ...    0.6463
# 25   good capable application help organize members...    0.8979
# 26   ive year least since two thousand thirteen fir...    0.3744
# 27                                    love app helpful    0.7906
# 28                                                good    0.4404
# 29                                                good    0.4404
# 30   finally fixed could log took well month alread...    0.2387
# 31                             wonderful use many year    0.5719
# 32   love app keep loyalty card one easy location w...    0.9616
# 33                     regal card disappeared get back   -0.2263
# 34   nice store fob one place never worry certain s...    0.5255
# 35   app show unavailable eu im u installed since t...    0.0000
# 36                                 great keeper record    0.6249
# 37                                     great way store    0.6249
# 38                             handy lot barcode saved    0.4215
# 39                                          using year    0.0000
# 40                               many year app problem   -0.4019
# 41   app still working barely asking log every time...   -0.7783
# 42                         login due overloaded server    0.0000
# 43   keep logging since last update happens infrequ...   -0.4019
# 44   cant log anymore keep saying server overloaded...    0.0000
# 45                                            easy use    0.4404
# 46                       keep saying server overloaded    0.0000
# 47                                                good    0.4404
# 48   card cant deleted unacceptable example fast pa...    0.5296
# 49                                      great app year    0.6249
# 50   would nice link appcards apple paygoogle pay u...    0.3400
# 51   soooo many permission look tracking wanted ok ...    0.7430
# 52   cant log support team back forth fee email tol...    0.4664
# 53   used work great cant delete old card successfu...    0.8750
# 54   used work well wont save card image accept edi...    0.4717
# 55   used lot useful constantly log insisting logge...    0.2263
# 56   used work well wont let sign reply server load...    0.5267
# 57                wont let log keep showing error code   -0.4019
# 58                                 convenient reliable    0.0000
# 59                                           best apps    0.6369
# 60      saying heavy traffic ay least week frustrating   -0.4404
# 61                                               great    0.6249
# 62   cant log app requiring log time try use get er...   -0.4019
# 63                                               great    0.6249
# 64   edit tried year still getting key ring isnt re...   -0.6222
# 65   awesome way free actual keyring little card st...    0.9022
# 66                              easy track reward card    0.7650
# 67                                   easy access great    0.7906
# 68                                                good    0.4404
# 69   used love app easy use practical forcing u log...    0.1531
# 70                           great way store info need    0.6249
# 71   use app occasionally work well would like know...    0.2315
# 72                          love handy dont carry card    0.6369
# 73   please create widget show multiple frequently ...    0.7906
# 74   handy library card little special card get clu...    0.3415
# 75            app keep sticking completely frustrating   -0.4927
# 76                                                work    0.0000
# 77                     dont carry bunch card put phone    0.0000
# 78                                             helpful    0.4215
# 79   captcha super ridiculous cant even log app any...    0.3400
# 80                                                easy    0.4404
# 81                                               handy    0.0000
# 82                            good app note part issue    0.4404
# 83                                        get job done    0.0000
# 84   great holding bar code get multiple nag screen...    0.1584
# 85                          great app one rarely issue    0.6249
# 86   fifteen attempt reset password found uninstall...    0.4215
# 87    garbage wont delete old card im going delete app    0.0000
# 88                     convenient allowed get rid card    0.0000
# 89                                        good feature    0.4404
# 90                                 say keep using card    0.0000
# 91                                      work perfectly    0.6369
# 92                  stop asking want turn notification   -0.2263
# 93                                       app good work    0.4404
# 94   used twelve year ok lately started asking allo...    0.1027
# 95              live card saved dont cary worry losing    0.7499
# 96   work fine record reward membership card use gi...    0.9260
# 97   using app forever keychain use wear every one ...    0.4939
# 98   cant delete old card go setting delete card ge...   -0.3400
# 99   seems dead june two thousand twenty-four site ...   -0.6486
# 100  app work well android phone keep location runn...   -0.3182
# 101                                          work year    0.0000
# 102                  still rocking thirteen year later    0.0000
# 103     seems worked flawlessly several year well done    0.4404
# 104                   except issue found app work well    0.2732
# 105                                              great    0.6249
# 106                                           love app    0.6369
# 107                                      great storage    0.6249
# 108  app year one update missing several card card ...   -0.6124
# 109                                  free wallet space    0.5106
# 110  cant add new card close app try add new cardsw...    0.0000
# 111                                   app need updated    0.0000
# 112               awesome app almost nine year problem    0.3947
# 113  installed app note eight perusal prior getting...    0.7184
# 114  would like use app every time go add card app ...   -0.0516
# 115  handy always phone wallet stuffed loyalty card...    0.7783
# 116  ive using year using keeping card problem let ...   -0.4019
# 117             unable edit delete card longer use app    0.0000
# 118                      always dont need wallet carry    0.0000
# 119  app good cant alphabetize card ive contacted s...    0.8225
# 120                               hard match scan code   -0.1027
# 121            much easier carrying bunch plastic card    0.4215
# 122  delete work cant delete old card using swipe a...    0.0000
# 123                                          excellent    0.5719
# 124                          work open take photo card    0.0000
# 125                         use list feature share lot    0.2960
# 126  love app make shopping list week time shop lis...    0.6369
# 127             love app need carry around thirty card    0.6369
# 128  update forty-two thousand , one hundred twenty...    0.0000
# 129                                   super convenient    0.5994
# 130                                               good    0.4404
# 131                        quick way find loyalty card    0.5423
# 132  best app storing store reward travel reward nu...    0.9169
# 133                keep crashing fresh install garbage    0.3182
# 134                                      easy use love    0.7964
# 135                            easy plastic card carry    0.4404
# 136  used app year awesome hated clogging wallet ke...   -0.0258
# 137                                         easy peasy    0.4404
# 138  longer show loyalty bar code useless tried rei...    0.5719
# 139                                          great app    0.6249
# 140                                            awesome    0.6249
# 141                                          love card    0.6369
# 142  handy eliminates carrying preferred customer c...    0.0000
# 143  decent app delete old card ive trying two year...    0.0000
# 144                                great shopping list    0.6249
# 145  need able add insurance card state id car regi...    0.6486
# 146                                    great app handy    0.6249
# 147                 keep use important document easily    0.4939
# 148  happened ive used app year suddenly card seque...   -0.2500
# 149                                          easy fast    0.4404
# 150  android fourteen reloads database logged edit ...   -0.7094
# 151  best app ever keeping information highly recom...    0.7902
# 152  got new phone loaded key ring app cant see bar...   -0.6597
# 153                                      fantastic app    0.5574
# 154  terrible interface impossible update easily re...   -0.1779
# 155                                          great app    0.6249
# 156                    easy use easy share card family    0.7906
# 157                           help keep wallet thinner    0.4019
# 158                       great easy use grocery store    0.7906
# 159  adding logo function doesnt work deleting card...    0.0000
# 160                                           easy use    0.4404
# 161  app gone flakey crash trying add card suggesti...   -0.4019
# 162  better could sort list way wanted like order g...    0.6597
# 163                                               work    0.0000
# 164                                               love    0.6369
# 165                                         convenient    0.0000
# 166  used great there much advertising cant find ca...    0.6249
# 167  physical card app work fine unfortunately cell...   -0.1531
# 168                                        good enough    0.4404
# 169                                          great app    0.6249
# 170                   nice shopping card home key ring    0.4215
# 171  used work great longer allows make edits unins...    0.6249
# 172                                         convenient    0.0000
# 173                                              handy    0.0000
# 174                                  availability easy    0.4404
# 175                                              handy    0.0000
# 176  cant delete old card like several month update...    0.2732
# 177                                  great convienient    0.6249
# 178                                         convenient    0.0000
# 179               always available forget tag key ring   -0.2263
# 180  handy consolidating one loyalty account centra...    0.5423
# 181                              work great convenient    0.6249
# 182                            great place get workout    0.6249
# 183  cant delete old card cant delete unused card a...    0.0772
# 184                                          great app    0.6249
# 185                               good selection price    0.4404
# 186                                    like convenient    0.3612
# 187                                   work better card    0.4404
# 188                                         work great    0.6249
# 189  loved worked delete card function didnt even w...    0.7490
# 190       great wallet much organized always card need    0.6249
# 191                                               nice    0.4215
# 192                                               good    0.4404
# 193                            love keyring convenient    0.6369
# 194                                    easy conveniant    0.4404
# 195  app constantly crash anytime try add store car...   -0.6597
# 196                                    work advertised    0.0000
# 197                                          great aop    0.6249
# 198                                     awesome thanks    0.7906
# 199  longer working lost image card support keep sa...    0.4082
# 200  cant delete update card good needed update lib...    0.6124
# 201                                          easytouse    0.0000
# 202  used love app loving anymore cant delete old c...    0.8442
# 203                                love card one place    0.6369
# 204  love reward card one place even happier one pl...    0.8934
# 205                                      excellent job    0.5719
# 206                                        simple work    0.0000
# 207                                               nice    0.4215
# 208                                     card one place    0.0000
# 209  great poor cant update card info cant add new ...    0.3120
# 210  app used work perfectly cant even view members...    0.6369
# 211                                           good app    0.4404
# 212  new permission thanks update might uninstall s...    0.5859
# 213                                          efficient    0.4215
# 214               great app keep track membership card    0.6249
# 215                          fantastic couldnt without    0.5574
# 216             generally work stand ad opening screen    0.0000
# 217  told friend app glad absolutely love dont carr...    0.8932
# 218                                               good    0.4404
# 219                love app keep track loyalty program    0.8271
# 220                                          great app    0.6249
# 221                                           easy use    0.4404
# 222             unable add new card edit existing card    0.0000
# 223                                    slow app popups    0.0000
# 224  convenient card one place phone bulky pile car...    0.6369
# 225                                   soooo convenient    0.0000
# 226  convenient carry small reward card one conveni...    0.5719
# 227  helpful app wish could identify bar code stand...    0.8402
# 228                                   cant delete card    0.0000
# 229              great dont need butt load little card    0.6249
# 230          messy key thing keep everything one place   -0.3612
# 231                          love app used eleven year    0.6369
# 232                          love everything one place    0.6369
# 233                      app losing pic card also info   -0.3818
# 234              like part difficult update card photo    0.0000
# 235            way invasive always trying track beware    0.0000
# 236  insisting knowing location despite repeated de...    0.0000
# 237                  convenient digital card one place    0.0000
# 238                                love card one place    0.6369
# 239                                     used better ok    0.6249
# 240  used able sort shopping list layout store app ...    0.0000
# 241  two thousand thirteen everywhere go people ama...    0.7308
# 242                              great experience glad    0.7964
# 243  loved app first came store membership gift car...    0.6597
# 244                              like card right phone    0.3612
# 245                                          work fine    0.2023
# 246           ever came app hat youit made life easier    0.4215
# 247  love electronic copy add insurance card covid ...    0.6369
# 248  excellent place track membership loyalty card ...    0.8020
# 249                                        always work    0.0000

# %% [markdown]
# <h5 style="font-size:1rem;">FidMe Loyalty Cards & Cashback</h5>

# %%
# Load preprocessed data from CSV
preprocessed_file = 'FidMe_reviews_preprocessed_reviews.csv'
df = pd.read_csv(preprocessed_file)

# Initialize VADER sentiment analyzer
sid = SentimentIntensityAnalyzer()

# Function to calculate polarity using VADER
def calculate_polarity_vader(review):
    scores = sid.polarity_scores(review)
    return scores['compound']

# Replace missing values in 'Preprocessed Text' column with an empty string
df['Preprocessed Text'].fillna('', inplace=True)

# Calculate polarity
df['Polarity'] = df['Preprocessed Text'].apply(lambda x: calculate_polarity_vader(x) if isinstance(x, str) else 0)

# app's package name
app_package_name = 'fr.snapp.fidme'

# Create a DataFrame with the explicit app package name
output_df_vader = pd.DataFrame({
    'App’s package name': [app_package_name] * len(df),
    'Review': df['Preprocessed Text'],
    'Polarity': df['Polarity']
})

# Limit to 250 reviews as required
output_df_vader = output_df_vader.head(250)

pd.set_option('display.max_rows', None)
display(output_df_vader)
# Out:
# <ipython-input-25-02a6ce69b13b>:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['
# 230     fr.snapp.fidme  getting worse update want customise card pictu...
# 231     fr.snapp.fidme                  nice app phone wear app sits spin
# 232     fr.snapp.fidme                                        helpful app
# 233     fr.snapp.fidme  absolutely love app using fidme year without w...
# 234     fr.snapp.fidme  give content french speak dutch everyone assum...
# 235     fr.snapp.fidme         crash phone fewer time tried keep crashing
# 236     fr.snapp.fidme                         app didnt display barcodes
# 237     fr.snapp.fidme                                                pay
# 238     fr.snapp.fidme  loved beep n go discontinued app would scan ca...
# 239     fr.snapp.fidme  despite bein australian using device location ...
# 240     fr.snapp.fidme          eficient time saving keeping loyalty card
# 241     fr.snapp.fidme  loyalty card one easy access app nothing fancy...
# 242     fr.snapp.fidme                                         convenient
# 243     fr.snapp.fidme                                           good app
# 244     fr.snapp.fidme  converted phone platform dreading recreate loy...
# 245     fr.snapp.fidme  amazing support ending changing email lost old...
# 246     fr.snapp.fidme  since update cant scan card anymore old one wo...
# 247     fr.snapp.fidme  dont really find coupon useful idea point app ...
# 248     fr.snapp.fidme  great idea tried didnt work card wouldnt scan ...
# 249     fr.snapp.fidme  really appreciate response support team app wi...
#
#      Polarity
# 0      0.0772
# 1      0.0000
# 2      0.3182
# 3      0.0000
# 4      0.0000
# 5      0.4019
# 6      0.0000
# 7      0.0000
# 8      0.0000
# 9      0.0772
# 10     0.0000
# 11     0.0000
# 12     0.1301
# 13     0.0000
# 14    -0.7184
# 15     0.9100
# 16    -0.2263
# 17     0.6659
# 18    -0.1027
# 19    -0.3400
# 20     0.5859
# 21     0.4404
# 22     0.4404
# 23     0.6249
# 24     0.4939
# 25    -0.1531
# 26     0.7650
# 27     0.4404
# 28     0.0000
# 29     0.0000
# 30     0.4601
# 31     0.0000
# 32     0.0000
# 33    -0.6858
# 34     0.6319
# 35     0.0000
# 36     0.4588
# 37    -0.5423
# 38    -0.5413
# 39     0.6249
# 40     0.3612
# 41     0.8074
# 42     0.0000
# 43     0.6597
# 44     0.4122
# 45     0.2023
# 46     0.5719
# 47     0.8532
# 48     0.9081
# 49     0.0000
# 50     0.4019
# 51     0.5423
# 52     0.0000
# 53     0.6249
# 54     0.0000
# 55     0.7732
# 56    -0.2732
# 57     0.6908
# 58     0.0772
# 59     0.0000
# 60     0.5719
# 61     0.4215
# 62     0.0000
# 63     0.4404
# 64     0.5859
# 65     0.6249
# 66     0.3657
# 67     0.0000
# 68     0.5719
# 69     0.7184
# 70     0.4404
# 71     0.7178
# 72     0.6369
# 73     0.6249
# 74     0.2023
# 75     0.7650
# 76     0.4404
# 77    -0.4767
# 78    -0.0258
# 79     0.0000
# 80     0.4939
# 81     0.0000
# 82     0.4404
# 83    -0.3818
# 84     0.6369
# 85     0.4404
# 86     0.6249
# 87     0.8074
# 88     0.8288
# 89     0.4215
# 90     0.6369
# 91     0.3612
# 92     0.0000
# 93     0.3182
# 94     0.2960
# 95     0.3182
# 96     0.0000
# 97    -0.1027
# 98     0.6908
# 99    -0.4215
# 100    0.5994
# 101   -0.1531
# 102    0.0000
# 103    0.6249
# 104    0.2960
# 105    0.0000
# 106    0.8020
# 107    0.4939
# 108    0.0951
# 109    0.8225
# 110    0.0000
# 111    0.4767
# 112    0.1999
# 113    0.0000
# 114    0.6249
# 115    0.6597
# 116    0.0000
# 117    0.0000
# 118    0.4404
# 119    0.4404
# 120    0.4404
# 121    0.4404
# 122    0.3182
# 123    0.4404
# 124    0.1764
# 125   -0.3818
# 126    0.2500
# 127    0.8750
# 128    0.4215
# 129    0.1531
# 130    0.6369
# 131    0.0000
# 132    0.0000
# 133    0.7003
# 134    0.0000
# 135   -0.4215
# 136    0.4404
# 137   -0.1027
# 138    0.0000
# 139    0.4215
# 140   -0.2316
# 141    0.5719
# 142    0.6249
# 143    0.5423
# 144    0.6124
# 145    0.4404
# 146    0.4404
# 147   -0.4215
# 148    0.7964
# 149    0.5994
# 150    0.6808
# 151    0.6249
# 152    0.8490
# 153    0.0000
# 154    0.6249
# 155    0.0000
# 156   -0.1027
# 157    0.0000
# 158    0.5141
# 159   -0.4588
# 160    0.8360
# 161   -0.0005
# 162   -0.0258
# 163    0.0000
# 164    0.5719
# 165    0.6249
# 166    0.7650
# 167    0.7184
# 168    0.4404
# 169    0.4215
# 170   -0.1027
# 171    0.8885
# 172    0.0000
# 173    0.0000
# 174    0.5423
# 175    0.8720
# 176    0.0000
# 177    0.6369
# 178    0.4404
# 179    0.9623
# 180    0.2960
# 181    0.6369
# 182    0.6249
# 183    0.3252
# 184    0.2732
# 185   -0.5994
# 186   -0.8040
# 187    0.8225
# 188    0.2732
# 189    0.6249
# 190    0.7003
# 191    0.9758
# 192    0.0000
# 193    0.7717
# 194    0.3612
# 195   -0.7269
# 196    0.4404
# 197    0.3999
# 198    0.0000
# 199    0.0000
# 200    0.9360
# 201    0.7531
# 202    0.0000
# 203    0.8934
# 204    0.0000
# 205   -0.4767
# 206   -0.4019
# 207   -0.2960
# 208    0.0516
# 209    0.3804
# 210    0.4404
# 211   -0.3612
# 212    0.6486
# 213    0.8822
# 214    0.6808
# 215    0.6369
# 216    0.3182
# 217    0.8885
# 218    0.4939
# 219    0.4927
# 220    0.0000
# 221    0.3400
# 222    0.9246
# 223    0.7906
# 224    0.0000
# 225    0.4404
# 226    0.0000
# 227    0.0000
# 228    0.7003
# 229    0.4404
# 230   -0.5859
# 231    0.4215
# 232    0.4215
# 233    0.8946
# 234    0.0000
# 235   -0.4019
# 236    0.0000
# 237   -0.1027
# 238    0.2960
# 239    0.6597
# 240    0.5423
# 241    0.8383
# 242    0.0000
# 243    0.4404
# 244    0.9022
# 245    0.7717
# 246   -0.0413
# 247    0.8678
# 248    0.2500
# 249    0.8795

# %% [markdown]
# <h5 style="font-size:1rem;">Pass2U Wallet - digitize cards</h5>

# %%
# Load preprocessed data from CSV
preprocessed_file = 'Pass2U_reviews_preprocessed_reviews.csv'
df = pd.read_csv(preprocessed_file)

# Initialize VADER sentiment analyzer
sid = SentimentIntensityAnalyzer()

# Function to calculate polarity using VADER
def calculate_polarity_vader(review):
    scores = sid.polarity_scores(review)
    return scores['compound']

# Replace missing values in 'Preprocessed Text' column with an empty string
df['Preprocessed Text'].fillna('', inplace=True)

# Calculate polarity
df['Polarity'] = df['Preprocessed Text'].apply(lambda x: calculate_polarity_vader(x) if isinstance(x, str) else 0)

# app's package name
app_package_name = 'com.passesalliance.wallet'

# Create a DataFrame with the explicit app package name
output_df_vader = pd.DataFrame({
    'App’s package name': [app_package_name] * len(df),
    'Review': df['Preprocessed Text'],
    'Polarity': df['Polarity']
})

# Limit to 250 reviews as required
output_df_vader = output_df_vader.head(250)

# Display
pd.set_option('display.max_rows', None)
display(output_df_vader)
# Out:
# <ipython-input-26-ad7b1507c5a4>:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Preprocessed Text'].fillna('', inplace=True)
#             App’s package name  \
# 0    com.passesalliance.wallet
# 1    com.passesalliance.wallet
# 2    com.passesalliance.wallet
# 3    com.passesalliance.wallet
# 4    com.passesalliance.wallet
# 5    com.passesalliance.wallet
# 6    com.passesalliance.wallet
# 7    com.passesalliance.wallet
# 8    com.passesalliance.wallet
# 9    com.passesalliance.wallet
# 10   com.passesalliance.wallet
# 11   com.passesalliance.wallet
# 12   com.passesalliance.wallet
# 13   com.passesalliance.wallet
# 14   com.passesalliance.wallet
# 15   com.passesalliance.wallet
# 16   com.passesalliance.wallet
# 17   com.passesalliance.wallet
# 18   com.passesalliance.wallet
# 19   com.passesalliance.wallet
# 20   com.passesalliance.wallet
# 21   com.passesalliance.wallet
# 22   com.passesalliance.wallet
# 23   com.passesalliance.wallet
# 24   com.passesalliance.wallet
# 25   com.passesalliance.wallet
# 26   com.passesalliance.wallet
# 27   com.passesalliance.wallet
# 28   com.passesalliance.wallet
# 29   com.passesalliance.wallet
# 30   com.passesalliance.wallet
# 31   com.passesalliance.wallet
# 32   com.passesalliance.wallet
# 33   com.passesalliance.wallet
# 34   com.passesalliance.wallet
# 35   com.passesalliance.wallet
# 36   com.passesalliance.wallet
# 37   com.passesalliance.wallet
# 38   com.passesalliance.wallet
# 39   com.passesalliance.wallet
# 40   com.passesalliance.wallet
# 41   com.passesalliance.wallet
# 42   com.passesalliance.wallet
# 43   com.passesalliance.wallet
# 44   com.passesalliance.wallet
# 45   com.passesalliance.wallet
# 46   com.passesalliance.wallet
# 47   com.passesalliance.wallet
# 48   com.passesalliance.wallet
# 49   com.passesalliance.wallet
# 50   com.passesalliance.wallet
# 51   com.passesalliance.wallet
# 52   com.passesalliance.wallet
# 53   com.passesalliance.wallet
# 54   com.passesalliance.wallet
# 55   com.passesalliance.wallet
# 56   com.passesalliance.wallet
# 57   com.passesalliance.wallet
# 58   com.passesalliance.wallet
# 59   com.passesalliance.wallet
# 60   com.passesalliance.wallet
# 61   com.passesalliance.wallet
# 62   com.passesalliance.wallet
# 63   com.passesalliance.wallet
# 64   com.passesalliance.wallet
# 65   com.passesalliance.wallet
# 66   com.passesalliance.wallet
# 67   com.passesalliance.wallet
# 68   com.passesalliance.wallet
# 69   com.passesalliance.wallet
# 70   com.passesalliance.wallet
# 71   com.passesalliance.wallet
# 72   com.passesalliance.wallet
# 73   com.passesalliance.wallet
# 74   com.passesalliance.wallet
# 75   com.passesalliance.wallet
# 76   com.passesalliance.wallet
# 77   com.passesalliance.wallet
# 78   com.passesalliance.wallet
# 79   com.passesalliance.wallet
# 80   com.passesalliance.wallet
# 81   com.passesalliance.wallet
# 82   com.passesalliance.wallet
# 83   com.passesalliance.wallet
# 84   com.passesalliance.wallet
# 85   com.passesalliance.wallet
# 86   com.passesalliance.wallet
# 87   com.passesalliance.wallet
# 88   com.passesalliance.wallet
# 89   com.passesalliance.wallet
# 90   com.passesalliance.wallet
# 91   com.passesalliance.wallet
# 92   com.passesalliance.wallet
# 93   com.passesalliance.wallet
# 94   com.passesalliance.wallet
# 95   com.passesalliance.wallet
# 96   com.passesalliance.wallet
# 97   com.passesalliance.wallet
# 98   com.passesalliance.wallet
# 99   com.passesalliance.wallet
# 100  com.passesalliance.wallet
# 101  com.passesalliance.wallet
# 102  com.passesalliance.wallet
# 103  com.passesalliance.wallet
# 104  com.passesalliance.wallet
# 105  com.passesalliance.wallet
# 106  com.passesalliance.wallet
# 107  com.passesalliance.wallet
# 108  com.passesalliance.wallet
# 109  com.passesalliance.wallet
# 110  com.passesalliance.wallet
# 111  com.passesalliance.wallet
# 112  com.passesalliance.wallet
# 113  com.passesalliance.wallet
# 114  com.passesalliance.wallet
# 115  com.passesalliance.wallet
# 116  com.passesalliance.wallet
# 117  com.passesalliance.wallet
# 118  com.passesalliance.wallet
# 119  com.passesalliance.wallet
# 120  com.passesalliance.wallet
# 121  com.passesalliance.wallet
# 122  com.passesalliance.wallet
# 123  com.passesalliance.wallet
# 124  com.passesalliance.wallet
# 125  com.passesalliance.wallet
# 126  com.passesalliance.wallet
# 127  com.passesalliance.wallet
# 128  com.passesalliance.wallet
# 129  com.passesalliance.wallet
# 130  com.passesalliance.wallet
# 131  com.passesalliance.wallet
# 132  com.passesalliance.wallet
# 133  com.passesalliance.wallet
# 134  com.passesalliance.wallet
# 135  com.passesalliance.wallet
# 136  com.passesalliance.wallet
# 137  com.passesalliance.wallet
# 138  com.passesalliance.wallet
# 139  com.passesalliance.wallet
# 140  com.passesalliance.wallet
# 141  com.passesalliance.wallet
# 142  com.passesalliance.wallet
# 143  com.passesalliance.wallet
# 144  com.passesalliance.wallet
# 145  com.passesalliance.wallet
# 146  com.passesalliance.wallet
# 147  com.passesalliance.wallet
# 148  com.passesalliance.wallet
# 149  com.passesalliance.wallet
# 150  com.passesalliance.wallet
# 151  com.passesalliance.wallet
# 152  com.passesalliance.wallet
# 153  com.passesalliance.wallet
# 154  com.passesalliance.wallet
# 155  com.passesalliance.wallet
# 156  com.passesalliance.wallet
# 157  com.passesalliance.wallet
# 158  com.passesalliance.wallet
# 159  com.passesalliance.wallet
# 160  com.passesalliance.wallet
# 161  com.passesalliance.wallet
# 162  com.passesalliance.wallet
# 163  com.passesalliance.wallet
# 164  com.passesalliance.wallet
# 165  com.passesalliance.wallet
# 166  com.passesalliance.wallet
# 167  com.passesalliance.wallet
# 168  com.passesalliance.wallet
# 169  com.passesalliance.wallet
# 170  com.passesalliance.wallet
# 171  com.passesalliance.wallet
# 172  com.passesalliance.wallet
# 173  com.passesalliance.wallet
# 174  com.passesalliance.wallet
# 175  com.passesalliance.wallet
# 176  com.passesalliance.wallet
# 177  com.passesalliance.wallet
# 178  com.passesalliance.wallet
# 179  com.passesalliance.wallet
# 180  com.passesalliance.wallet
# 181  com.passesalliance.wallet
# 182  com.passesalliance.wallet
# 183  com.passesalliance.wallet
# 184  com.passesalliance.wallet
# 185  com.passesalliance.wallet
# 186  com.passesalliance.wallet
# 187  com.passesalliance.wallet
# 188  com.passesalliance.wallet
# 189  com.passesalliance.wallet
# 190  com.passesalliance.wallet
# 191  com.passesalliance.wallet
# 192  com.passesalliance.wallet
# 193  com.passesalliance.wallet
# 194  com.passesalliance.wallet
# 195  com.passesalliance.wallet
# 196  com.passesalliance.wallet
# 197  com.passesalliance.wallet
# 198  com.passesalliance.wallet
# 199  com.passesalliance.wallet
# 200  com.passesalliance.wallet
# 201  com.passesalliance.wallet
# 202  com.passesalliance.wallet
# 203  com.passesalliance.wallet
# 204  com.passesalliance.wallet
# 205  com.passesalliance.wallet
# 206  com.passesalliance.wallet
# 207  com.passesalliance.wallet
# 208  com.passesalliance.wallet
# 209  com.passesalliance.wallet
# 210  com.passesalliance.wallet
# 211  com.passesalliance.wallet
# 212  com.passesalliance.wallet
# 213  com.passesalliance.wallet
# 214  com.passesalliance.wallet
# 215  com.passesalliance.wallet
# 216  com.passesalliance.wallet
# 217  com.passesalliance.wallet
# 218  com.passesalliance.wallet
# 219  com.passesalliance.wallet
# 220  com.passesalliance.wallet
# 221  com.passesalliance.wallet
# 222  com.passesalliance.wallet
# 223  com.passesalliance.wallet
# 224  com.passesalliance.wallet
# 225  com.passesalliance.wallet
# 226  com.passesalliance.wallet
# 227  com.passesalliance.wallet
# 228  com.passesalliance.wallet
# 229  com.passesalliance.wallet
# 230  com.passesalliance.wallet
# 231  com.passesalliance.wallet
# 232  com.passesalliance.wallet
# 233  com.passesalliance.wallet
# 234  com.passesalliance.wallet
# 235  com.passesalliance.wallet
# 236  com.passesalliance.wallet
# 237  com.passesalliance.wallet
# 238  com.passesalliance.wallet
# 239  com.passesalliance.wallet
# 240  com.passesalliance.wallet
# 241  com.passesalliance.wallet
# 242  com.passesalliance.wallet
# 243  com.passesalliance.wallet
# 244  com.passesalliance.wallet
# 245  com.passesalliance.wallet
# 246  com.passesalliance.wallet
# 247  com.passesalliance.wallet
# 248  com.passesalliance.wallet
# 249  com.passesalliance.wallet
#
#                                                 Review  Polarity
# 0    zoo belong say use app hold membership card fi...    0.3182
# 1    good simple effective update happened ui geniu...    0.9238
# 2    everything work layout seems old android versi...    0.5267
# 3                                                 work    0.0000
# 4                                             easy use    0.4404
# 5    updated recently midnov two thousand twenty-fo...   -0.1531
# 6                                                 love    0.6369
# 7    app simple easy use love clean interface altho...    0.9590
# 8                                folk one thousand ten    0.0000
# 9           use wear app upgrade please purchase phone    0.3182
# 10   useless concept app ever download qr code tick...    0.8126
# 11                                         cool wallet    0.3182
# 12                                     dont understand    0.0000
# 13                                   confusing useless   -0.5719
# 14                           working two month working    0.0000
# 15                                        helpful easy    0.6908
# 16                                           brilliant    0.5859
# 17   kiliza mazungumzo ya manabii kupitia vitabu vi...    0.0000
# 18                                                love    0.6369
# 19                                           fast easy    0.4404
# 20                                 convenient easy use    0.4404
# 21   five star app used pass2u pro forever sadly fe...    0.3182
# 22                         easy install use seems okay    0.5859
# 23          easy convenient messing around sheet paper    0.4404
# 24                                 try get sign b apps    0.0000
# 25   work want change phone terrible ok pay able sw...    0.3274
# 26   best apps pas kindly update general card desig...    0.8658
# 27                                love lovely blessing    0.9042
# 28                                    work great issue    0.6249
# 29                              nothing good thing say   -0.3412
# 30                                     dont understand    0.0000
# 31   use credit card info differently named company...    0.3818
# 32       last year app great year suck get phone today    0.2960
# 33   wrong paper post u older generation forced soc...   -0.3400
# 34   there problem sharing pkpass gmail io always s...    0.3182
# 35                                          useful app    0.4404
# 36   information whatsoever app purchase pricing ev...    0.3818
# 37                                                fine    0.2023
# 38   easy use feature rich allows creating template...    0.8779
# 39   work hardly removed another star import google...   -0.0772
# 40                      restore purchase working phone    0.2960
# 41                                    helpful easy use    0.6908
# 42      good ticket special event used wwe event great    0.8658
# 43                   parece que funciona correctamente    0.0000
# 44   say free try charge card three thousand , nine...    0.5106
# 45   wont allow restore paid upgrade pro asks confi...   -0.3724
# 46   see flaw although neither compare apps since f...    0.4404
# 47                          started using app far good    0.4404
# 48                                            love app    0.6369
# 49                                     scam fraudulent   -0.7845
# 50   cant find pdfs screenshot ticket add barcodes ...   -0.7430
# 51                                            horrible   -0.5423
# 52          issue app easy use handy ticket card place    0.4404
# 53                                               great    0.6249
# 54                        good way save membership etc    0.7269
# 55                                            easy use    0.4404
# 56        constantly wipe membership progress gong cha    0.4215
# 57                                   useful simple app    0.4404
# 58                           cant add location like io   -0.2755
# 59                      doesnt open file used much use    0.0000
# 60   muy practico el sistema te evitar de recoger b...    0.0000
# 61                          longer recognises pdf file    0.0000
# 62                                          ok foe job   -0.1779
# 63   failed work ticketek australia pkpass link tic...   -0.6703
# 64                                    absolute garbage    0.0000
# 65   restore pro possible changing phone pay beside...    0.2023
# 66   app store love remote desktop connection googl...    0.6369
# 67   backup working export import sd paid restore p...    0.2960
# 68   like app found couple thing could improved con...    0.6808
# 69   able restore purchase app broke previous phone...    0.5423
# 70   pésima todo se dificulta hay nada que innovar ...    0.0000
# 71                 dont buy cant restore purchase scam    0.5654
# 72   restore purchase respond via email edit really...   -0.3182
# 73   straight fraud forced try use app download tic...   -0.6599
# 74                        life go money inportant life    0.0000
# 75           app wont open file cant print need ticket    0.0000
# 76                                    download 2nd pas    0.0000
# 77                                              simple    0.0000
# 78                              really neat app useful    0.7548
# 79   cool app always ready need never faced issue k...    0.7717
# 80   really good app whatever reason download pas t...   -0.4215
# 81   bad app way hard basic stuff like adding item ...    0.1280
# 82   aware card need backed signing account restore...    0.7845
# 83                                            eta gege    0.0000
# 84   unable restore pro version new device still ca...    0.0803
# 85   exactly say accepting apple wallet pass quickl...    0.8689
# 86                                   restored purchase    0.3400
# 87                                  work four ten time    0.0000
# 88   import pkpass file app recommended company off...    0.2023
# 89   import pkpass file referred company bought adm...   -0.4404
# 90      recognize pdf file although asking pdf useless   -0.4215
# 91                            cant restore pro version   -0.2235
# 92   downloaded app instantly charged credit card f...    0.2023
# 93   oregon zoo made download access ticket get del...    0.0000
# 94   exactly supposed never problem good update sti...    0.4122
# 95                         expiry date saved card show    0.4215
# 96   longer load pass cant even open aeroflot pas r...    0.2023
# 97   easy use add direct pdf ticket management most...    0.8020
# 98   store downloaded ticket make easily accessible...    0.3400
# 99   contains deceptive scam ad result credit card ...   -0.4588
# 100  ill give three star bought pro switched device...   -0.5702
# 101                           cant restore pro version   -0.2235
# 102                            notification wont clear   -0.2924
# 103                                               work    0.0000
# 104  curious app need access contact want setup bac...    0.3818
# 105  work described use import apple wallet boardin...    0.8225
# 106  hello change device cant restore pro version s...   -0.2235
# 107                                               need    0.0000
# 108                                    work like charm    0.6369
# 109                         find document read qr code    0.0000
# 110                                       great gadget    0.6249
# 111             easy work better googlepay samsung pay    0.6597
# 112  uploaded several boarding pass failed scanned ...   -0.5106
# 113  great place quick id card prof membership used...    0.6249
# 114                                 practical easy use    0.4404
# 115  say tin flexible could little bit polish thoug...    0.7783
# 116           fake description cant recognize pdf file   -0.4767
# 117                                         有時登不進去 請改善    0.0000
# 118                                    easy use lovely    0.7717
# 119                         cant store covid green pas    0.0000
# 120  android app ok feel outdated functional wearos...   -0.3283
# 121      aweful would scan barcodes invaliduninstslled    0.0000
# 122  great looking app love however dont know get a...    0.9001
# 123  upgrade change phone need pay app link gmail i...   -0.1027
# 124                                         quick easy    0.4404
# 125         track date expected track payment okay app    0.2263
# 126                                            working    0.0000
# 127                                         great easy    0.7906
# 128  cant restore pro version account bought uninst...    0.4959
# 129                         terrible app user friendly    0.0258
# 130  тромава не интуитивна претендира множество неж...    0.0000
# 131                        extremely helpful fast easy    0.7397
# 132                                 buena para eventos    0.0000
# 133                                              super    0.5994
# 134  publish pas store default prevent polluting pu...    0.0258
# 135                      life saver come membership id    0.0000
# 136                      didnt work qr code import pdf    0.0000
# 137  lovely app happy pass2u suggestion please add ...    0.8689
# 138                               app work well thanks    0.6124
# 139  publish pas store yes change simply making per...    0.6369
# 140  didnt remember purchased wanted purchase reins...    0.0000
# 141  serf purpose mobile app phone free adsupport h...    0.8402
# 142  super helpful use iphone style pass android ap...    0.7717
# 143  using several year great make ticketing simple...    0.7906
# 144  upgraded pro want loyalty card smart watch ins...    0.7579
# 145                                            useless   -0.4215
# 146         харесва ми не съм го разучи още но е добро    0.0000
# 147                                              great    0.6249
# 148                     scan small even using template    0.0000
# 149  app work intended galaxy note twenty ultra err...   -0.4019
# 150  commercial practice obscure say least ive paid...   -0.2960
# 151     good app train ticket upgraded use smart watch    0.6808
# 152                    still sure supposed option icon    0.3182
# 153                         wear o behind pay wall bad   -0.5994
# 154  frustratingly still load image update supposed...   -0.4588
# 155                   uninstalled within two min awful   -0.4588
# 156  freeze reading qr code return error reading co...   -0.3612
# 157  app real easy use convenient way carry certifi...    0.4404
# 158  bought premium version hope make template unfo...   -0.6486
# 159  device dark mode pass color change unexpectedl...   -0.3612
# 160  unable add image custom pass always get editin...   -0.2411
# 161                                                 wi    0.0000
# 162  sucksno place enter code dealer issued bar cod...    0.0000
# 163                                         work great    0.6249
# 164  latest update havent able create new pas alway...    0.7569
# 165  tried dozen similar apps app useful feature ex...    0.6249
# 166                            每次重裝或換新手機會員卡都沒辦法帶過去根本折騰    0.0000
# 167    first hard understand get use great application    0.5719
# 168                               keep getting smarter    0.4588
# 169                                               bien    0.0000
# 170                                garbage spam adware   -0.3612
# 171  used app collecting drink stamp everytime purc...    0.8402
# 172                                               nice    0.4215
# 173  terrible never work store macquarie centre sel...    0.4082
# 174                                  photo crop editor    0.0000
# 175                            drain battery dont kill    0.5773
# 176                                               good    0.4404
# 177                                            хихихих    0.0000
# 178                                never used old care   -0.3875
# 179                       great app wallet lot thinner    0.6249
# 180  cant transfer point dont purchase app change p...   -0.2924
# 181                                               cool    0.3182
# 182                   freeze android eight hundred ten    0.0516
# 183  paid pro latest version two thousand , one hun...   -0.1531
# 184                                             ok den    0.2960
# 185  completely destoryed app longer back ups googl...   -0.7645
# 186                               quick easy excellent    0.7650
# 187  problem pas neared expiry geetting continuous ...    0.0516
# 188  paid pro version android iphone backup restore...   -0.2023
# 189  able backup google drive give dropbox alternative    0.0000
# 190  backup doesnt work spent lot time setting pass...    0.2960
# 191            cant select downloaded file import pass    0.0000
# 192                          many ad notification spam   -0.3612
# 193  easy use handy dont want carry load membership...    0.3975
# 194                                      reimbursement    0.0000
# 195  kept crashing reported screen every time event...   -0.4019
# 196  keep sending notification stopped uninstalled ...    0.1531
# 197                           crash background deleted   -0.4019
# 198                                              crash   -0.4019
# 199  virtually unusable due constant chirping notif...    0.6675
# 200  phone reported app crashed running background ...   -0.5574
# 201                                              crush   -0.1531
# 202                     getting constant error message   -0.4019
# 203  since last update persistently stop running ba...   -0.2960
# 204                 crashed use unplugged usb phone pc    0.0000
# 205  year loyalty card suddenly started repeatedly ...    0.6597
# 206           constant error message since last update   -0.4019
# 207            constantly crash background time delete   -0.4019
# 208                                           dont use    0.0000
# 209                                 battery drain open    0.0000
# 210     tried obtaining location month last opened app    0.0000
# 211  horrible uploaded pdf several page ticket app ...   -0.5423
# 212  ad ruining app small menu button hidden behind...   -0.6249
# 213                                            perfect    0.5719
# 214                                             useful    0.4404
# 215  otherwise good even premium design design temp...   -0.4588
# 216                easy self explanatory app great app    0.7906
# 217  would great add auto restore option like exist...    0.8316
# 218                                              great    0.6249
# 219                                 awesome app period    0.6249
# 220                                 easy user friendly    0.7269
# 221  could much better hint auto archive setting do...    0.6908
# 222                                        gut feeling    0.1280
# 223             easy usemost event use itno need print    0.4404
# 224                                               good    0.4404
# 225                                            improve    0.4404
# 226                                               love    0.6369
# 227                                 doesnt scan coupon    0.0000
# 228  well app cant read file phone pixel two pretty...   -0.0516
# 229  name spelt wrong people corrected pas 2u walle...   -0.2960
# 230                             amazing work excellent    0.8176
# 231                            great connectivity apps    0.6249
# 232  would love say eight star wont let worth littl...    0.7938
# 233                                      doesnt update    0.0000
# 234  email seamlessly integration useful applicatio...    0.7003
# 235  worst app ever u cant even pas simple ticket b...   -0.6249
# 236           developer many similar notification time    0.0000
# 237                                     convenient use    0.0000
# 238  downloaded airport etickets easy use entering ...    0.4404
# 239  created five card made backup uninstall reinst...    0.5267
# 240                          полезно лесно за употреба    0.0000
# 241           great app lot function cheap pro version    0.6249
# 242                    indespensible appt bulky wallet    0.0000
# 243                                    really helpfull    0.0000
# 244                     work properly one boarding pas    0.0000
# 245  scan card blackberry mobile key2 running lates...    0.1027
# 246         great app keep pass one place holiday love    0.9001
# 247                  always pleased satisfy visit shop    0.7096
# 248  template longer loading cant save favorite tem...   -0.6816
# 249                                          work fine    0.2023

# %% [markdown]
# <h3 style="font-size:2rem;">Sentiment Analysis Comparison</h3>

# %% [markdown]
# One can find various trends when we compare sentiment analysis data from tools such as TextBlob and VADER with an app's rating. App ratings usually reflect the thoughts of the collective user base. However, sentiment analysis technologies such as TextBlob and VADER evaluate the emotional content of individual reviews, providing a more detailed picture of user sentiment. One can frequently observe a relationship between sentiment analysis findings and app ratings. Sentiment analysis algorithms typically give higher-rated apps higher sentiment scores, while lower-rated apps may exhibit a greater prevalence of negative sentiment in user reviews. Nonetheless, disparities may emerge from a multitude of sources. For example, an app with a good overall rating may contain individual ratings that show discontent or specific difficulties. In such circumstances, sentiment analysis techniques may detect negative attitudes despite the app's overall positive rating. Conversely, an app with a lower rating may have some positive reviews highlighting specific features or experiences, leading to a more balanced sentiment analysis outcome. An in-depth knowledge of the rating distribution of the app as well as the attitude expressed in individual reviews is necessary to interpret these similarities and discrepancies. Though sentiment analysis offers more in-depth insights into the underlying feelings and ideas influencing those evaluations, app ratings still give a comprehensive picture of user happiness. Stakeholders can uncover opportunities for improvement and more research by combining the two methods to have a thorough grasp of user feedback.

# %% [markdown]
# <h3 style="font-size:2rem;">Prompt Engineering</h3>

# %% [markdown]
# a) The prompt that I would use for for GPT-3 sentiment evaluation is the following: "Please provide a sentiment analysis for the given the review: (insert review (preprocessed text review))."
# b) I would make a table with the review text, the TextBlob sentiment polarity score, and the sentiment label (e.g., positive, negative, or neutral) in order to compare the sentiment produced by the GPT model with the results of TextBlob. After that, we can include a second column for the sentiment label that GPT-3 produced.
# c) Similarly, I would make another table with the review text, Vader sentiment polarity score, and sentiment label in order to compare the sentiment produced by the GPT model with the results of Vader. I will once more add a column to represent the sentiment label produced by GPT-3 and contrast it with Vader's labels. This comparison will shed light on how well the sentiment analysis carried out by GPT-3 matches the Vader findings.

# %% [markdown]
# GPT-3 vs. TextBlob Examples

# %%
data = {
    'App Package Name': ['de.stocard.stocard', 'com.froogloid.kring.google.zxing.client.android', 'fr.snapp.fidme'],
    #'Review Text': ['Great option', 'Never a problem, easy to use, very helpful. I tell my friends', 'I was unable to scan it in any of the shops I went to.'],
    'Preprocessed Text': ['great option', 'never problem easy use helpful tell friend', 'unable scan shop went'],
    'TextBlob Polarity': [0.800000, 0.433333, -0.500000],
    'GPT-3 Sentiment': ['positive', 'positive', 'negative']
}

df = pd.DataFrame(data)
print(df.to_string(index=False))
# Out:
#                                App Package Name                          Preprocessed Text  TextBlob Polarity GPT-3 Sentiment
#                              de.stocard.stocard                               great option           0.800000        positive
# com.froogloid.kring.google.zxing.client.android never problem easy use helpful tell friend           0.433333        positive
#                                  fr.snapp.fidme                      unable scan shop went          -0.500000        negative

# %% [markdown]
# GPT-3 vs. Vader Examples

# %%
data = {
    'App Package Name': ['de.stocard.stocard', 'fr.snapp.fidme', 'com.passesalliance.wallet'],
    'Preprocessed Text': ['convenient', 'junk freezing phone watch', 'uninstalled within two min awful'],
    'Vader': [0.0000, -0.1027, -0.4588],
    'GPT-3 Sentiment': ['positive', 'negative', 'negative']
}

df = pd.DataFrame(data)
print(df.to_string(index=False))
# Out:
#          App Package Name                Preprocessed Text   Vader GPT-3 Sentiment
#        de.stocard.stocard                       convenient  0.0000        positive
#            fr.snapp.fidme        junk freezing phone watch -0.1027        negative
# com.passesalliance.wallet uninstalled within two min awful -0.4588        negative

# %% [markdown]
# <h3 style="font-size:2rem;">Create LDA Model</h3>

# %%
# !pip install --upgrade --force-reinstall numpy
# !pip install --upgrade --force-reinstall gensim
# Out:
# Collecting numpy
#   Downloading numpy-2.2.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 3.6 MB/s eta 0:00:00
# Downloading numpy-2.2.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 28.6 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gensim 4.3.3 requires numpy<2.0,>=1.18.5, but you have numpy 2.2.4 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.2.4 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.2.4 which is incompatible.
# Successfully installed numpy-2.2.4
# Collecting gensim
#   Using cached gensim-4.3.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Collecting numpy<2.0,>=1.18.5 (from gensim)
#   Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting scipy<1.14.0,>=1.7.0 (from gensim)
#   Using cached scipy-1.13.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Collecting smart-open>=1.8.1 (from gensim)
#   Downloading smart_open-7.1.0-py3-none-any.whl.metadata (24 kB)
# Collecting wrapt (from smart-open>=1.8.1->gensim)
#   Downloading wrapt-1.17.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Using cached gensim-4.3.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.7 MB)
# Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
# Using cached scipy-1.13.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.6 MB)
# Downloading smart_open-7.1.0-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 2.5 MB/s eta 0:00:00
# Downloading wrapt-1.17.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.2/83.2 kB 3.3 MB/s eta 0:00:00
# Installing collected packages: wrapt, numpy, smart-open, scipy, gensim
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.17.2
#     Uninstalling wrapt-1.17.2:
#       Successfully uninstalled wrapt-1.17.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.4
#     Uninstalling numpy-2.2.4:
#       Successfully uninstalled numpy-2.2.4
#   Attempting uninstall: smart-open
#     Found existing installation: smart-open 7.1.0
#     Uninstalling smart-open-7.1.0:
#       Successfully uninstalled smart-open-7.1.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.13.1
#     Uninstalling scipy-1.13.1:
#       Successfully uninstalled scipy-1.13.1
#   Attempting uninstall: gensim
#     Found existing installation: gensim 4.3.3
#     Uninstalling gensim-4.3.3:
#       Successfully uninstalled gensim-4.3.3
# Successfully installed gensim-4.3.3 numpy-1.26.4 scipy-1.13.1 smart-open-7.1.0 wrapt-1.17.2

# %%
from gensim import corpora
from gensim.models import LdaModel

# %% [markdown]
# <h5 style="font-size:1rem;">Stocard - Rewards Cards Wallet</h5>

# %%
# Load preprocessed data from CSV
input_file = 'Stocard_reviews_preprocessed_reviews.csv'
df = pd.read_csv(input_file)

df['split_reviews'] = df['Preprocessed Text'].str.split()
df.dropna(subset=['split_reviews'], inplace=True)

corpora_reviews = df['split_reviews'].tolist()
dictionary = corpora.Dictionary(corpora_reviews)
corpus = [dictionary.doc2bow(review) for review in corpora_reviews]

num_topics = 15
lda_model = LdaModel(corpus=corpus, id2word=dictionary, num_topics=num_topics, passes=12)

for topic in lda_model.print_topics(num_words=7):
    print(topic)
# Out:
# (0, '0.124*"really" + 0.079*"code" + 0.078*"better" + 0.053*"bar" + 0.050*"problem" + 0.048*"using" + 0.044*"app"')
# (1, '0.124*"scanner" + 0.111*"key" + 0.046*"barcodes" + 0.043*"brilliant" + 0.041*"little" + 0.037*"chain" + 0.032*"needed"')
# (2, '0.128*"card" + 0.075*"one" + 0.067*"wallet" + 0.053*"app" + 0.048*"place" + 0.045*"much" + 0.042*"handy"')
# (3, '0.466*"great" + 0.241*"app" + 0.027*"cloud" + 0.025*"wallet" + 0.011*"must" + 0.009*"everyone" + 0.009*"car"')
# (4, '0.072*"phone" + 0.069*"card" + 0.053*"get" + 0.047*"stocard" + 0.039*"wallet" + 0.029*"got" + 0.027*"new"')
# (5, '0.342*"work" + 0.108*"well" + 0.043*"app" + 0.041*"excellent" + 0.027*"doesnt" + 0.026*"job" + 0.020*"time"')
# (6, '0.340*"use" + 0.310*"easy" + 0.087*"convenient" + 0.065*"simple" + 0.019*"set" + 0.018*"cool" + 0.012*"user"')
# (7, '0.058*"card" + 0.047*"app" + 0.020*"would" + 0.017*"time" + 0.015*"store" + 0.014*"like" + 0.014*"one"')
# (8, '0.130*"card" + 0.061*"scan" + 0.060*"store" + 0.032*"like" + 0.027*"number" + 0.025*"barcode" + 0.020*"add"')
# (9, '0.088*"idea" + 0.057*"say" + 0.055*"perfect" + 0.041*"free" + 0.036*"exactly" + 0.035*"amazing" + 0.031*"looking"')
# (10, '0.164*"card" + 0.100*"love" + 0.089*"wallet" + 0.054*"carry" + 0.052*"app" + 0.037*"dont" + 0.035*"need"')
# (11, '0.144*"awesome" + 0.074*"app" + 0.051*"yet" + 0.043*"recommend" + 0.031*"u" + 0.030*"catalogue" + 0.030*"list"')
# (12, '0.061*"five" + 0.056*"star" + 0.032*"android" + 0.027*"update" + 0.026*"support" + 0.026*"working" + 0.023*"watch"')
# (13, '0.164*"nice" + 0.104*"thanks" + 0.075*"app" + 0.035*"look" + 0.035*"issue" + 0.033*"device" + 0.026*"enter"')
# (14, '0.238*"good" + 0.135*"app" + 0.102*"far" + 0.097*"best" + 0.059*"space" + 0.030*"ever" + 0.024*"fantastic"')

# %% [markdown]
# <h5 style="font-size:1rem;">Key Ring: Loyalty Card App</h5>

# %%
input_file = 'KeyRing_reviews_preprocessed_reviews.csv'
df = pd.read_csv(input_file)

df['split_reviews'] = df['Preprocessed Text'].str.split()
df.dropna(subset=['split_reviews'], inplace=True)

corpora_reviews = df['split_reviews'].tolist()
dictionary = corpora.Dictionary(corpora_reviews)
corpus = [dictionary.doc2bow(review) for review in corpora_reviews]

num_topics = 15
lda_model = LdaModel(corpus=corpus, id2word=dictionary, num_topics=num_topics, passes=12)

for topic in lda_model.print_topics(num_words=7):
    print(topic)
# Out:
# (0, '0.121*"code" + 0.100*"bar" + 0.034*"fix" + 0.027*"please" + 0.018*"galaxy" + 0.017*"must" + 0.017*"ok"')
# (1, '0.088*"nice" + 0.071*"yet" + 0.067*"havent" + 0.038*"app" + 0.028*"working" + 0.026*"really" + 0.024*"notification"')
# (2, '0.112*"droid" + 0.058*"card" + 0.048*"tried" + 0.036*"scanned" + 0.031*"worked" + 0.028*"store" + 0.023*"retailer"')
# (3, '0.062*"would" + 0.049*"great" + 0.038*"star" + 0.038*"five" + 0.038*"concept" + 0.030*"could" + 0.026*"idea"')
# (4, '0.144*"scan" + 0.095*"scanner" + 0.074*"store" + 0.049*"screen" + 0.044*"barcode" + 0.043*"read" + 0.037*"cant"')
# (5, '0.418*"work" + 0.118*"doesnt" + 0.093*"great" + 0.038*"well" + 0.029*"evo" + 0.026*"didnt" + 0.018*"tried"')
# (6, '0.061*"app" + 0.038*"card" + 0.030*"update" + 0.023*"force" + 0.022*"time" + 0.021*"close" + 0.020*"try"')
# (7, '0.073*"card" + 0.049*"like" + 0.045*"cool" + 0.037*"app" + 0.025*"htc" + 0.022*"one" + 0.021*"store"')
# (8, '0.204*"great" + 0.141*"app" + 0.091*"idea" + 0.087*"key" + 0.050*"ring" + 0.050*"best" + 0.021*"excellent"')
# (9, '0.042*"never" + 0.035*"manually" + 0.035*"card" + 0.031*"number" + 0.026*"two" + 0.023*"enter" + 0.023*"u"')
# (10, '0.052*"app" + 0.040*"cv" + 0.020*"screen" + 0.020*"use" + 0.017*"used" + 0.016*"phone" + 0.016*"using"')
# (11, '0.202*"good" + 0.069*"far" + 0.062*"worked" + 0.058*"app" + 0.052*"update" + 0.030*"convenient" + 0.023*"widget"')
# (12, '0.186*"love" + 0.126*"app" + 0.098*"use" + 0.092*"awesome" + 0.058*"easy" + 0.044*"useful" + 0.034*"time"')
# (13, '0.046*"perfect" + 0.042*"new" + 0.037*"thanks" + 0.029*"bad" + 0.029*"ad" + 0.028*"shop" + 0.027*"version"')
# (14, '0.175*"card" + 0.037*"love" + 0.036*"app" + 0.036*"dont" + 0.033*"carry" + 0.032*"reward" + 0.031*"keep"')

# %% [markdown]
# <h5 style="font-size:1rem;">FidMe Loyalty Cards & Cashback</h5>

# %%
input_file = 'FidMe_reviews_preprocessed_reviews.csv'
df = pd.read_csv(input_file)

df['split_reviews'] = df['Preprocessed Text'].str.split()
df.dropna(subset=['split_reviews'], inplace=True)

corpora_reviews = df['split_reviews'].tolist()
dictionary = corpora.Dictionary(corpora_reviews)
corpus = [dictionary.doc2bow(review) for review in corpora_reviews]

num_topics = 15
lda_model = LdaModel(corpus=corpus, id2word=dictionary, num_topics=num_topics, passes=12)

for topic in lda_model.print_topics(num_words=7):
    print(topic)
# Out:
# (0, '0.074*"card" + 0.050*"app" + 0.027*"easy" + 0.024*"loyalty" + 0.021*"dont" + 0.019*"carry" + 0.018*"store"')
# (1, '0.049*"de" + 0.022*"et" + 0.013*"le" + 0.013*"carte" + 0.011*"je" + 0.011*"card" + 0.011*"cant"')
# (2, '0.058*"card" + 0.045*"work" + 0.040*"app" + 0.020*"scan" + 0.015*"doesnt" + 0.014*"great" + 0.013*"barcode"')
# (3, '0.064*"card" + 0.044*"app" + 0.011*"please" + 0.010*"watch" + 0.010*"update" + 0.010*"add" + 0.010*"get"')
# (4, '0.046*"app" + 0.022*"work" + 0.021*"good" + 0.020*"card" + 0.014*"time" + 0.013*"logo" + 0.011*"account"')
# (5, '0.031*"work" + 0.026*"card" + 0.025*"use" + 0.020*"app" + 0.017*"tried" + 0.017*"useful" + 0.016*"scan"')
# (6, '0.022*"card" + 0.017*"good" + 0.010*"number" + 0.009*"use" + 0.009*"dont" + 0.009*"discount" + 0.009*"different"')
# (7, '0.036*"great" + 0.022*"card" + 0.018*"app" + 0.016*"use" + 0.013*"way" + 0.012*"lot" + 0.010*"language"')
# (8, '0.041*"card" + 0.035*"app" + 0.022*"phone" + 0.016*"wallet" + 0.015*"time" + 0.015*"store" + 0.013*"lot"')
# (9, '0.061*"card" + 0.040*"app" + 0.032*"love" + 0.018*"one" + 0.016*"scan" + 0.015*"loyalty" + 0.013*"place"')
# (10, '0.054*"app" + 0.017*"card" + 0.016*"need" + 0.015*"like" + 0.014*"time" + 0.011*"fidme" + 0.011*"adding"')
# (11, '0.053*"app" + 0.038*"card" + 0.016*"use" + 0.014*"add" + 0.013*"really" + 0.013*"phone" + 0.012*"cant"')
# (12, '0.034*"app" + 0.033*"use" + 0.028*"nice" + 0.026*"better" + 0.024*"much" + 0.019*"easy" + 0.019*"uninstalled"')
# (13, '0.034*"card" + 0.034*"good" + 0.016*"work" + 0.015*"version" + 0.013*"dont" + 0.012*"store" + 0.012*"like"')
# (14, '0.041*"app" + 0.028*"card" + 0.018*"doesnt" + 0.016*"watch" + 0.013*"fidme" + 0.011*"use" + 0.011*"excellent"')

# %% [markdown]
# <h3 style="font-size:1rem;">Topic Modelling</h3>

# %% [markdown]
# <h5 style="font-size:1rem;">Pass2U Wallet - digitize cards</h5>

# %%
input_file = 'Pass2U_reviews_preprocessed_reviews.csv'
df = pd.read_csv(input_file)

df['split_reviews'] = df['Preprocessed Text'].str.split()
df.dropna(subset=['split_reviews'], inplace=True)

corpora_reviews = df['split_reviews'].tolist()
dictionary = corpora.Dictionary(corpora_reviews)
corpus = [dictionary.doc2bow(review) for review in corpora_reviews]

num_topics = 15
lda_model = LdaModel(corpus=corpus, id2word=dictionary, num_topics=num_topics, passes=12)

for topic in lda_model.print_topics(num_words=7):
    print(topic)
# Out:
# (0, '0.027*"card" + 0.023*"app" + 0.012*"ticket" + 0.012*"add" + 0.010*"brilliant" + 0.010*"really" + 0.009*"would"')
# (1, '0.033*"app" + 0.024*"like" + 0.018*"background" + 0.016*"best" + 0.014*"wallet" + 0.014*"pass" + 0.014*"scan"')
# (2, '0.034*"app" + 0.030*"convenient" + 0.027*"handy" + 0.022*"time" + 0.020*"one" + 0.018*"get" + 0.012*"ten"')
# (3, '0.035*"app" + 0.021*"add" + 0.020*"ticket" + 0.018*"boarding" + 0.017*"pas" + 0.015*"like" + 0.014*"pass"')
# (4, '0.083*"good" + 0.048*"app" + 0.048*"great" + 0.021*"cant" + 0.021*"version" + 0.019*"restore" + 0.016*"card"')
# (5, '0.105*"use" + 0.101*"easy" + 0.062*"work" + 0.029*"well" + 0.012*"app" + 0.011*"dont" + 0.010*"helpful"')
# (6, '0.041*"pas" + 0.038*"app" + 0.029*"boarding" + 0.027*"awesome" + 0.019*"use" + 0.018*"easy" + 0.017*"work"')
# (7, '0.022*"app" + 0.017*"work" + 0.016*"pass" + 0.012*"far" + 0.011*"ticket" + 0.010*"cant" + 0.010*"passbook"')
# (8, '0.034*"love" + 0.027*"app" + 0.017*"pas" + 0.012*"great" + 0.011*"used" + 0.011*"get" + 0.009*"card"')
# (9, '0.058*"app" + 0.045*"boarding" + 0.036*"pass" + 0.021*"pas" + 0.015*"screen" + 0.012*"nice" + 0.011*"way"')
# (10, '0.045*"app" + 0.030*"ticket" + 0.026*"useful" + 0.020*"one" + 0.016*"would" + 0.015*"time" + 0.014*"work"')
# (11, '0.028*"app" + 0.020*"qr" + 0.018*"code" + 0.017*"useless" + 0.015*"file" + 0.013*"ticket" + 0.013*"wont"')
# (12, '0.055*"app" + 0.020*"great" + 0.016*"pass" + 0.014*"work" + 0.011*"pas" + 0.010*"boarding" + 0.009*"use"')
# (13, '0.032*"simple" + 0.019*"work" + 0.019*"excellent" + 0.014*"use" + 0.013*"app" + 0.013*"quick" + 0.012*"easy"')
# (14, '0.033*"say" + 0.031*"wallet" + 0.021*"work" + 0.020*"apple" + 0.016*"pas" + 0.015*"pass" + 0.015*"boarding"')

# %% [markdown]
# <h5 style="font-size:1rem;">Stocard - Rewards Cards Wallet</h5>

# %%
data = {
    'Functionality': [
        'Digitize Your Rewards Cards',
        'Collect Rewards Points in Stocard',
        'Discover Exclusive Offers',
        'Use Advanced Features'
    ],
    'Related Topic IDs': [
        '0, 12',
        '3, 11',
        '5, 10',
        '2, 8'
    ]
}

df = pd.DataFrame(data)
pd.set_option('display.max_colwidth', None)
print(df.to_string(index=False))
# Out:
#                     Functionality Related Topic IDs
#       Digitize Your Rewards Cards             0, 12
# Collect Rewards Points in Stocard             3, 11
#         Discover Exclusive Offers             5, 10
#             Use Advanced Features              2, 8

# %% [markdown]
# <h5 style="font-size:1rem;">Key Ring: Loyalty Card App</h5>

# %%
data = {
    'Functionality': [
        'Barcode Scanner',
        'Loyalty Card Database',
        'Remote Cloud Backup',
        'Favorites and Shopping Lists',
        'Sharing and Notifications'
    ],
    'Related Topic IDs': [
        '5, 11',
        '2, 11',
        '7, 13',
        '2, 9, 10',
        '8, 10'
    ]
}

df = pd.DataFrame(data)
pd.set_option('display.max_colwidth', None)
print(df.to_string(index=False))
# Out:
#                Functionality Related Topic IDs
#              Barcode Scanner             5, 11
#        Loyalty Card Database             2, 11
#          Remote Cloud Backup             7, 13
# Favorites and Shopping Lists          2, 9, 10
#    Sharing and Notifications             8, 10

# %% [markdown]
# <h5 style="font-size:1rem;">FidMe Loyalty Cards & Cashback</h5>

# %%
data = {
    'Functionality': [
        'Digitize Your Loyalty Cards',
        'Organize Your Paper Receipts',
        'Discover Deals and Discounts'
    ],
    'Related Topic IDs': [
        '0, 4, 7, 9, 11, 12, 13',
        '2, 6',
        '1, 3, 5, 8, 10, 14'
    ]
}
df = pd.DataFrame(data)
pd.set_option('display.max_colwidth', None)
print(df.to_string(index=False))
# Out:
#                Functionality      Related Topic IDs
#  Digitize Your Loyalty Cards 0, 4, 7, 9, 11, 12, 13
# Organize Your Paper Receipts                   2, 6
# Discover Deals and Discounts     1, 3, 5, 8, 10, 14

# %% [markdown]
# <h5 style="font-size:1rem;">Pass2U Wallet - digitize cards</h5>

# %%
data = {
    'Functionality': [
        'Collect and manage membership cards, coupons, event tickets, movies tickets, transport cards, and etc.',
        'Support QR Code, Aztec, PDF417 2D barcodes, and Code 128 1D barcode.',
        'Show the relevant passes on the lock screen according to current location or time.',
        'Support for iBeacon.',
        'Support changing notifications of Apple Wallet pass.',
        'Localization of passes.',
        'Scan/Enter the barcodes on your cards or tickets to make passes and save them in Pass2U Wallet.',
        'Free Pass update API for Pass2U Wallet issuers.',
        'Google Drive backup and restore.',
        'Wear OS app support for pro user.'
    ],
    'Related Topic IDs': [
        '1, 4, 6, 7, 11, 12, 14',
        '3',
        '5',
        '3',
        '5',
        '6',
        '7',
        '8',
        '8',
        '10'
    ]
}

df = pd.DataFrame(data)
pd.set_option('display.max_colwidth', None)
print(df.to_string(index=False))
# Out:
#                                                                                          Functionality      Related Topic IDs
# Collect and manage membership cards, coupons, event tickets, movies tickets, transport cards, and etc. 1, 4, 6, 7, 11, 12, 14
#                                   Support QR Code, Aztec, PDF417 2D barcodes, and Code 128 1D barcode.                      3
#                     Show the relevant passes on the lock screen according to current location or time.                      5
#                                                                                   Support for iBeacon.                      3
#                                                   Support changing notifications of Apple Wallet pass.                      5
#                                                                                Localization of passes.                      6
#        Scan/Enter the barcodes on your cards or tickets to make passes and save them in Pass2U Wallet.                      7
#                                                        Free Pass update API for Pass2U Wallet issuers.                      8
#                                                                       Google Drive backup and restore.                      8
#                                                                      Wear OS app support for pro user.                     10

# %% [markdown]
# <h3 style="font-size:2rem;">About Topic Modelling</h3>

# %% [markdown]
# The topics comparing to the topics extracted from reviews of other apps (similar/competitor) is done above.

# %% [markdown]
# Topic modeling is a powerful technique that allows us to uncover hidden patterns and topics within large volumes of text data efficiently. By applying topic modeling to user reviews of mobile applications like Stocard, KeyRing, FidMe, and Pass2U, we can gain valuable insights into how users perceive these apps and how their functionalities align with the feedback provided.
#
# Reviews from users of Stocard have been examined to extract a variety of themes, including the app's performance, ease of use, convenience, and digitization of loyalty cards. These subjects closely resemble the features that Stocard has been promoting on Google Play. For instance, Stocard's feature that lets users scan and save their loyalty cards digitally, clearing up space in their physical wallets and streamlining the rewards collection procedure, is a perfect fit with the highlighted subjects about digitizing rewards cards and earning rewards points.
#
# In the same way, topic modeling provides information about how users perceive and interact with Key Ring, FidMe, and Pass2U.
#
# User reviews on barcode scanning and loyalty card databases are consistent with Key Ring's capabilities of scanning barcode loyalty cards and offering remote cloud backup.
#
# FidMe's emphasis on deal-finding, receipt organization, and card management is seen in its themes on finding special offers, managing cards, and dealings.
#
# Features of Pass2U, like its simplicity of use and support for multiple pass kinds, align with discussions about the app's use and compatibility with various pass types.
#
# When it comes to comprehending user input and evaluating how well an app's features match users' expectations and experiences, topic modeling is a useful technique. Developers can increase user satisfaction, fix bugs, and improve their apps by identifying recurring themes and issues in user evaluations.

# %%
def format_topics_sentences(ldamodel, corpus, texts):

    sent_topics_df = pd.DataFrame()


    for i, row in enumerate(ldamodel[corpus]):
        row = sorted(row, key=lambda x: (x[1]), reverse=True)

        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # Dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                row_data = [int(topic_num), round(prop_topic, 4), topic_keywords]
                sent_topics_df = pd.concat([sent_topics_df, pd.DataFrame([row_data], columns=['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords'])], ignore_index=True)
                break

    sent_topics_df['Review'] = texts

    sent_topics_df = sent_topics_df.sort_values(by=['Dominant_Topic', 'Perc_Contribution'], ascending=[False, False])

    return sent_topics_df

df_topic_sents_keywords = format_topics_sentences(ldamodel=lda_model, corpus=corpus, texts=data)

print(df_topic_sents_keywords.head(1200))
# Out:
#       Dominant_Topic  Perc_Contribution  \
# 604               14             0.9783
# 85                14             0.9689
# 551               14             0.9641
# 395               14             0.9556
# 371               14             0.9533
# 229               14             0.9481
# 539               14             0.9417
# 542               14             0.9417
# 1002              14             0.9417
# 368               14             0.9151
# 744               14             0.9151
# 471               14             0.9067
# 532               14             0.9067
# 283               14             0.8963
# 112               14             0.8833
# 422               14             0.8833
# 684               14             0.8833
# 56                14             0.8667
# 822               14             0.8667
# 247               14             0.8444
# 375               14             0.8444
# 416               14             0.8444
# 394               14             0.8133
# 1043              14             0.8133
# 1114              14             0.7694
# 963               14             0.7667
# 447               14             0.7666
# 611               14             0.7666
# 372               14             0.6889
# 457               14             0.6889
# 641               14             0.6889
# 736               14             0.6889
# 865               14             0.6889
# 897               14             0.6889
# 961               14             0.6889
# 1101    NaN
# 423     NaN
# 592     NaN
# 324     NaN
# 431     NaN
# 785     NaN
# 862     NaN
# 990     NaN
# 565     NaN
# 870     NaN
# 940     NaN
# 646     NaN
# 997     NaN
# 467     NaN
# 25      NaN
# 493     NaN
# 879     NaN
# 958     NaN
# 156     NaN
# 420     NaN
# 256     NaN
# 574     NaN
# 433     NaN
# 496     NaN
# 248     NaN
# 598     NaN
# 659     NaN
# 559     NaN
# 913     NaN
# 403     NaN
# 480     NaN
# 874     NaN
# 54      NaN
# 262     NaN
# 1042    NaN
# 706     NaN
# 1105    NaN
# 1128    NaN
# 62      NaN
# 186     NaN
# 230     NaN
# 319     NaN
# 320     NaN
# 621     NaN
# 666     NaN
# 770     NaN
# 836     NaN
# 1073    NaN
# 1090    NaN
# 343     NaN
# 1026    NaN
# 800     NaN
# 77      NaN
# 325     NaN
# 478     NaN
# 599     NaN
# 738     NaN
# 808     NaN
# 842     NaN
# 926     NaN
# 434     NaN
# 900     NaN
# 804     NaN
# 124     NaN
# 761     NaN
# 9       NaN
# 881     NaN
# 1142    NaN
# 10      NaN
# 1       NaN
# 632     NaN
# 1119    NaN
# 984     NaN
# 440     NaN
# 948     NaN
# 21      NaN
# 259     NaN
# 1121    NaN
# 508     NaN
# 519     NaN
# 957     NaN
# 742     NaN
# 331     NaN
# 787     NaN
# 910     NaN
# 235     NaN
# 1093    NaN
# 99      NaN
# 877     NaN
# 1034    NaN
# 1125    NaN
# 266     NaN
# 427     NaN
# 690     NaN
# 894     NaN
# 962     NaN
# 339     NaN
# 618     NaN
# 928     NaN
# 1032    NaN
# 851     NaN
# 938     NaN
# 600     NaN
# 829     NaN
# 593     NaN
# 723     NaN
# 150     NaN
# 267     NaN
# 460     NaN
# 148     NaN
# 155     NaN
# 129     NaN
# 406     NaN
# 494     NaN
# 902     NaN
# 28      NaN
# 582     NaN
# 702     NaN
# 711     NaN
# 774     NaN
# 982     NaN
# 430     NaN
# 426     NaN
# 566     NaN
# 402     NaN
# 1006    NaN
# 750     NaN
# 281     NaN
# 580     NaN
# 596     NaN
# 638     NaN
# 688     NaN
# 701     NaN
# 755     NaN
# 896     NaN
# 1013    NaN
# 789     NaN
# 732     NaN
# 223     NaN
# 1120    NaN
# 1107    NaN
# 548     NaN
# 949     NaN
# 1004    NaN
# 65      NaN
# 860     NaN
# 220     NaN
# 527     NaN
# 816     NaN
# 966     NaN
# 280     NaN
# 330     NaN
# 410     NaN
# 758     NaN
# 166     NaN
# 22      NaN
# 113     NaN
# 269     NaN
# 138     NaN
# 965     NaN
# 1069    NaN
# 115     NaN
# 581     NaN
# 286     NaN
# 377     NaN
# 807     NaN
# 299     NaN
# 619     NaN
# 980     NaN
# 576     NaN
# 75      NaN
# 775     NaN
# 1077    NaN
# 90      NaN
# 116     NaN
# 136     NaN
# 153     NaN
# 544     NaN
# 763     NaN
# 886     NaN
# 236     NaN
# 253     NaN
# 312     NaN
# 381     NaN
# 14      NaN
# 841     NaN
# 1029    NaN
# 102     NaN
# 806     NaN
# 809     NaN
# 882     NaN
# 13      NaN
# 83      NaN
# 384     NaN
# 654     NaN
# 729     NaN
# 1140    NaN
# 1104    NaN
# 872     NaN
# 752     NaN
# 606     NaN
# 59      NaN
# 820     NaN
# 145     NaN
# 201     NaN
# 333     NaN
# 792     NaN
# 852     NaN
# 899     NaN
# 998     NaN
# 815     NaN
# 27      NaN
# 388     NaN
# 739     NaN
# 1131    NaN
# 227     NaN
# 19      NaN
# 643     NaN
# 221     NaN
# 687     NaN
# 735     NaN
# 801     NaN
# 396     NaN
# 327     NaN
# 887     NaN
# 282     NaN
# 0       NaN
# 63      NaN
# 679     NaN
# 878     NaN
# 123     NaN
# 730     NaN
# 585     NaN
# 649     NaN
# 810     NaN
# 954     NaN
# 607     NaN
# 357     NaN
# 537     NaN
# 866     NaN
# 1108    NaN
# 79      NaN
# 362     NaN
# 487     NaN
# 151     NaN
# 463     NaN
# 536     NaN
# 1116    NaN
# 125     NaN
# 942     NaN
# 664     NaN
# 848     NaN
# 352     NaN
# 975     NaN
# 995     NaN
# 1024    NaN
# 1053    NaN
# 43      NaN
# 78      NaN
# 418     NaN
# 428     NaN
# 781     NaN
# 973     NaN
# 1007    NaN
# 479     NaN
# 57      NaN
# 613     NaN
# 692     NaN
# 1147    NaN
# 232     NaN
# 35      NaN
# 233     NaN
# 243     NaN
# 293     NaN
# 390     NaN
# 449     NaN
# 728     NaN
# 901     NaN
# 1000    NaN
# 699     NaN
# 246     NaN
# 988     NaN
# 1057    NaN
# 82      NaN
# 190     NaN
# 950     NaN
# 345     NaN
# 107     NaN
# 181     NaN
# 214     NaN
# 366     NaN
# 414     NaN
# 483     NaN
# 597     NaN
# 718     NaN
# 840     NaN
# 856     NaN
# 1038    NaN
# 272     NaN
# 288     NaN
# 52      NaN
# 623     NaN
# 924     NaN
# 1083    NaN
# 244     NaN
# 531     NaN
# 952     NaN
# 521     NaN
# 873     NaN
# 1027    NaN
# 11      NaN
# 217     NaN
# 979     NaN
# 120     NaN
# 1067    NaN
# 968     NaN
# 821     NaN
# 275     NaN
# 571     NaN
# 731     NaN
# 969     NaN
# 795     NaN
# 245     NaN
# 1050    NaN
# 971     NaN
# 417     NaN
# 748     NaN
# 452     NaN
# 1018    NaN
# 46      NaN
# 504     NaN
# 1056    NaN
# 252     NaN
# 365     NaN
# 408     NaN
# 609     NaN
# 824     NaN
# 529     NaN
# 260     NaN
# 608     NaN
# 162     NaN
# 363     NaN
# 349     NaN
# 442     NaN
# 601     NaN
# 678     NaN
# 210     NaN
# 459     NaN
# 558     NaN
# 636     NaN
# 1133    NaN
# 268     NaN
# 328     NaN
# 674     NaN
# 868     NaN
# 1102    NaN
# 240     NaN
# 310     NaN
# 341     NaN
# 387     NaN
# 549     NaN
# 756     NaN
# 858     NaN
# 981     NaN
# 1041    NaN
# 564     NaN
# 976     NaN
# 556     NaN
# 1117    NaN
# 196     NaN
# 284     NaN
# 435     NaN
# 170     NaN
# 439     NaN
# 563     NaN
# 1031    NaN
# 1136    NaN
# 498     NaN
# 376     NaN
# 932     NaN
# 507     NaN
# 344     NaN
# 639     NaN
# 1064    NaN
# 64      NaN
# 222     NaN
# 520     NaN
# 111     NaN
# 364     NaN
# 534     NaN
# 790     NaN
# 974     NaN
# 912     NaN
# 1112    NaN
# 1122    NaN
# 977     NaN
# 346     NaN
# 996     NaN
# 817     NaN
# 929     NaN
# 109     NaN
# 986     NaN
# 733     NaN
# 180     NaN
# 172     NaN
# 250     NaN
# 270     NaN
# 311     NaN
# 469     NaN
# 764     NaN
# 797     NaN
# 1054    NaN
# 1141    NaN
# 161     NaN
# 605     NaN
# 367     NaN
# 185     NaN
# 456     NaN
# 474     NaN
# 945     NaN
# 81      NaN
# 476     NaN
# 386     NaN
# 918     NaN
# 987     NaN
# 983     NaN
# 453     NaN
# 893     NaN
# 615     NaN
# 1091    NaN
# 139     NaN
# 1086    NaN
# 5       NaN
# 164     NaN
# 33      NaN
# 923     NaN
# 554     NaN
# 1099    NaN
# 329     NaN
# 473     NaN
# 620     NaN
# 846     NaN
# 575     NaN
# 66      NaN
# 92      NaN
# 944     NaN
# 1076    NaN
# 883     NaN
# 741     NaN
# 999     NaN
# 74      NaN
# 178     NaN
# 670     NaN
# 76      NaN
# 888     NaN
# 1014    NaN
# 168     NaN
# 890     NaN
# 205     NaN
# 48      NaN
# 465     NaN
# 614     NaN
# 805     NaN
# 717     NaN
# 257     NaN
# 937     NaN
# 189     NaN
# 6       NaN
# 18      NaN
# 169     NaN
# 194     NaN
# 226     NaN
# 380     NaN
# 627     NaN
# 802     NaN
# 898     NaN
# 1134    NaN
# 1138    NaN
# 332     NaN
# 38      NaN
# 1088    NaN
# 142     NaN
# 993     NaN
# 569     NaN
# 39      NaN
# 446     NaN
# 871     NaN
# 567     NaN
# 960     NaN
# 100     NaN
# 1049    NaN
# 289     NaN
# 876     NaN
# 1095    NaN
# 709     NaN
# 835     NaN
# 1023    NaN
# 577     NaN
# 920     NaN
# 96      NaN
# 462     NaN
# 502     NaN
# 629     NaN
# 685     NaN
# 1085    NaN
# 1089    NaN
# 34      NaN
# 432     NaN
# 579     NaN
# 831     NaN
# 557     NaN
# 1055    NaN
# 1048    NaN
# 747     NaN
# 773     NaN
# 1037    NaN
# 1118    NaN
# 191     NaN
# 515     NaN
# 287     NaN
# 616     NaN
# 1030    NaN
# 1124    NaN
# 656     NaN
# 782     NaN
# 595     NaN
# 216     NaN
# 249     NaN
# 279     NaN
# 1028    NaN
# 424     NaN
# 292     NaN
# 714     NaN
# 1040    NaN
# 58      NaN
# 385     NaN
# 37      NaN
# 297     NaN
# 8       NaN
# 953     NaN
# 951     NaN
# 1008    NaN
# 1097    NaN
# 131     NaN
# 361     NaN
# 184     NaN
# 158     NaN
# 1106    NaN
# 80      NaN
# 1123    NaN
# 2       NaN
# 694     NaN
# 448     NaN
# 1063    NaN
# 187     NaN
# 238     NaN
# 1132    NaN
# 70      NaN
# 481     NaN
# 813     NaN
# 978     NaN
# 1070    NaN
# 786     NaN
# 930     NaN
# 1021    NaN
# 745     NaN
# 516     NaN
# 935     NaN
# 760     NaN
# 959     NaN
# 628     NaN
# 864     NaN
# 1009    NaN
# 1051    NaN
# 1152    NaN
# 242     NaN
# 334     NaN
# 538     NaN
# 892     NaN
# 1074    NaN
# 489     NaN
# 219     NaN
# 304     NaN
# 359     NaN
# 857     NaN
# 855     NaN
# 530     NaN
# 703     NaN
# 936     NaN
# 415     NaN
# 514     NaN
# 547     NaN
# 255     NaN
# 648     NaN
# 263     NaN
# 389     NaN
# 660     NaN
# 751     NaN
# 796     NaN
# 799     NaN
# 895     NaN
# 1062    NaN
# 970     NaN
# 721     NaN
# 1060    NaN
# 844     NaN
# 1065    NaN
# 712     NaN
# 411     NaN
# 301     NaN
# 1035    NaN
# 612     NaN
# 917     NaN
# 215     NaN
# 336     NaN
# 441     NaN
# 342     NaN
# 658     NaN
# 722     NaN
# 130     NaN
# 472     NaN
# 509     NaN
# 193     NaN
# 146     NaN
# 378     NaN
# 429     NaN
# 495     NaN
# 555     NaN
# 726     NaN
# 98      NaN
# 652     NaN
# 1144    NaN
# 204     NaN
# 182     NaN
# 562     NaN
# 588     NaN
# 825     NaN
# 398     NaN
# 546     NaN
# 695     NaN
# 875     NaN
# 1020    NaN
# 1081    NaN
# 228     NaN
# 41      NaN
# 399     NaN
# 486     NaN
# 631     NaN
# 640     NaN
# 833     NaN
# 947     NaN
# 1003    NaN
# 174     NaN
# 1061    NaN
# 4       NaN
# 15      NaN
# 49      NaN
# 55      NaN
# 208     NaN
# 285     NaN
# 296     NaN
# 316     NaN
# 464     NaN
# 505     NaN
# 560     NaN
# 617     NaN
# 626     NaN
# 704     NaN
# 716     NaN
# 768     NaN
# 769     NaN
# 818     NaN
# 830     NaN
# 885     NaN
# 905     NaN
# 964     NaN
# 1079    NaN
# 173     NaN
# 655     NaN
# 553     NaN
# 916     NaN
# 3       NaN
# 103     NaN
# 413     NaN
# 468     NaN
# 522     NaN
# 568     NaN
# 570     NaN
# 610     NaN
# 644     NaN
# 843     NaN
# 854     NaN
# 869     NaN
# 939     NaN
# 811     NaN
# 832     NaN
# 118     NaN
# 20      NaN
# 409     NaN
# 673     NaN
# 491     NaN
# 421     NaN
# 326     NaN
# 859     NaN
# 967     NaN
# 779     NaN
# 791     NaN
# 850     NaN
# 114     NaN
# 71      NaN
# 1046    NaN
# 772     NaN
# 309     NaN
# 698     NaN
# 490     NaN
# 175     NaN
# 354     NaN
# 1130    NaN
# 383     NaN
# 759     NaN
# 657     NaN
# 127     NaN
# 573     NaN
# 931     NaN
# 1011    NaN
# 144     NaN
# 134     NaN
# 183     NaN
# 212     NaN
# 143     NaN
# 518     NaN
# 94      NaN
# 84      NaN
# 552     NaN
# 662     NaN
# 749     NaN
# 106     NaN
# 819     NaN
# 67      NaN
# 650     NaN
# 681     NaN
# 591     NaN
# 661     NaN
# 757     NaN
# 523     NaN
# 812     NaN
# 17      NaN
# 561     NaN
# 586     NaN
# 149     NaN
# 461     NaN
# 47      NaN
# 271     NaN
# 393     NaN
# 676     NaN
# 891     NaN
# 1098    NaN
# 743     NaN
# 40      NaN
# 91      NaN
# 101     NaN
# 192     NaN
# 202     NaN
# 278     NaN
# 803     NaN
# 209     NaN
# 443     NaN
# 475     NaN
# 710     NaN
# 382     NaN
# 647     NaN
# 241     NaN
# 258     NaN
# 444     NaN
# 454     NaN
# 512     NaN
# 624     NaN
# 633     NaN
# 668     NaN
# 762     NaN
# 788     NaN
# 823     NaN
# 907     NaN
# 908     NaN
# 911     NaN
# 914     NaN
# 915     NaN
# 1022    NaN
# 1047    NaN
# 1139    NaN
# 45      NaN
# 199     NaN
# 128     NaN
# 29      NaN
# 667     NaN
# 32      NaN
# 777     NaN
# 206     NaN
# 179     NaN
# 140     NaN
# 458     NaN
# 724     NaN
# 69      NaN
# 53      NaN
# 126     NaN
# 147     NaN
# 176     NaN
# 213     NaN
# 218     NaN
# 224     NaN
# 265     NaN
# 277     NaN
# 290     NaN
# 294     NaN
# 295     NaN
# 298     NaN
# 305     NaN
# 306     NaN
# 315     NaN
# 318     NaN
# 323     NaN
# 340     NaN
# 353     NaN
# 391     NaN
# 405     NaN
# 419     NaN
# 436     NaN
# 438     NaN
# 540     NaN
# 590     NaN
# 594     NaN
# 622     NaN
# 625     NaN
# 642     NaN
# 663     NaN
# 665     NaN
# 677     NaN
# 705     NaN
# 707     NaN
# 753     NaN
# 766     NaN
# 771     NaN
# 784     NaN
# 838     NaN
# 921     NaN
# 933     NaN
# 991     NaN
# 1005    NaN
# 1058    NaN
# 1092    NaN
# 1110    NaN
# 1129    NaN
# 1150    NaN
# 177     NaN
# 264     NaN
# 497     NaN
# 1126    NaN
# 889     NaN
# 630     NaN
# 635     NaN
# 725     NaN
# 746     NaN
# 1100    NaN
# 356     NaN
# 163     NaN
# 880     NaN
# 919     NaN
# 1143    NaN
# 86      NaN
# 188     NaN
# 455     NaN
# 720     NaN
# 925     NaN
# 903     NaN
# 794     NaN
# 105     NaN
# 1149    NaN
# 776     NaN
# 195     NaN
# 778     NaN
# 941     NaN
# 671     NaN
# 89      NaN
# 437     NaN
# 506     NaN
# 525     NaN
# 60      NaN
# 314     NaN
# 686     NaN
# 634     NaN
# 1084    NaN
# 1109    NaN
# 68      NaN
# 501     NaN
# 160     NaN
# 510     NaN
# 93      NaN
# 603     NaN
# 31      NaN
# 234     NaN
# 466     NaN
# 754     NaN
# 943     NaN
# 946     NaN
# 351     NaN
# 358     NaN
# 584     NaN
# 1148    NaN
# 167     NaN
# 651     NaN
# 740     NaN
# 337     NaN
# 300     NaN
# 727     NaN
# 1039    NaN
# 1146    NaN
# 24      NaN
# 119     NaN
# 1045    NaN
# 1096    NaN
# 26      NaN
# 1036    NaN
# 61      NaN
# 261     NaN
# 307     NaN
# 834     NaN
# 994     NaN
# 165     NaN
# 308     NaN
# 335     NaN
# 369     NaN
# 719     NaN
# 922     NaN
# 231     NaN
# 828     NaN
# 1019    NaN
# 97      NaN
# 42      NaN
# 141     NaN
# 583     NaN
# 12      NaN
# 30      NaN
# 1025    NaN
# 117     NaN
# 291     NaN
# 669     NaN
# 88      NaN
# 587     NaN
# 526     NaN
# 737     NaN
# 50      NaN
# 133     NaN
# 589     NaN
# 683     NaN
# 700     NaN
# 934     NaN
# 1111    NaN
# 645     NaN
# 578     NaN
# 122     NaN
# 152     NaN
# 370     NaN
# 780     NaN
# 1082    NaN
# 693     NaN
# 1059    NaN
# 972     NaN
# 355     NaN
# 1080    NaN
# 171     NaN
# 72      NaN
# 373     NaN
# 845     NaN
# 798     NaN
# 211     NaN
# 1078    NaN
# 847     NaN
# 697     NaN
# 470     NaN
# 251     NaN
# 400     NaN
# 992     NaN
# 765     NaN
# 839     NaN
# 1012    NaN
# 484     NaN
# 317     NaN
# 407     NaN
# 653     NaN
# 675     NaN
# 783     NaN
# 397     NaN
# 321     NaN
# 51      NaN
# 225     NaN
# 445     NaN
# 485     NaN
# 543     NaN
# 689     NaN
# 767     NaN
# 956     NaN
# 87      NaN
# 535     NaN
# 157     NaN
# 237     NaN
# 274     NaN
# 322     NaN
# 861     NaN
# 904     NaN
# 488     NaN
# 1010    NaN
# 348     NaN
# 200     NaN
# 500     NaN
# 347     NaN
# 513     NaN
# 137     NaN
# 1135    NaN
# 154     NaN
# 849     NaN
# 1115    NaN
# 276     NaN
# 1145    NaN
# 1033    NaN
# 545     NaN
# 826     NaN
# 108     NaN
# 197     NaN
# 533     NaN
# 1052    NaN
# 360     NaN
# 482     NaN
# 511     NaN
# 528     NaN
# 637     NaN
# 708     NaN
# 713     NaN
# 793     NaN
# 955     NaN
# 1094    NaN
# 1068    NaN
# 691     NaN
# 203     NaN
# 198     NaN
# 302     NaN
# 404     NaN
# 412     NaN
# 517     NaN
# 680     NaN
# 837     NaN
# 853     NaN
# 909     NaN
# 132     NaN
# 1015    NaN
# 207     NaN
# 682     NaN
# 121     NaN
# 550     NaN
# 1151    NaN
# 927     NaN
# 425     NaN
# 73      NaN
# 524     NaN
# 1016    NaN
# 1127    NaN
# 477     NaN
# 814     NaN
# 36      NaN
# 503     NaN
# 1071    NaN
# 44      NaN
# 492     NaN
# 379     NaN
# 541     NaN
# 159     NaN
# 827     NaN
# 499     NaN
# 1087    NaN
# 104     NaN
# 239     NaN
# 350     NaN
# 985     NaN
# 572     NaN
# 1017    NaN
# 867     NaN
# 273     NaN
# 374     NaN
# 450     NaN
# 602     NaN
# 1137    NaN
# 95      NaN
# 715     NaN
# 1001    NaN
# 7       NaN
# 989     NaN
# 338     NaN
# 884     NaN
# 1113    NaN
# 906     NaN
# 16      NaN
# 254     NaN
# 303     NaN
# 734     NaN
# 451     NaN
# 392     NaN
# 1044    NaN
# 863     NaN
# 672     NaN
# 110     NaN
# 401     NaN
# 23      NaN

# %% [markdown]
# The review with the highest percentage contribution is review # 271.
#
# The dominant topic is: 15 (because the first one starts from 0).
#
# The highest percent contribution is: 0.9806.
#
# The dominant topic #15 is: card, app, store, excellent, need, carry, wallet, phone, one, love.
#
# The preprocessed review is: scanned store card day later wallet stolen convenient card barcodes qr code smartphone used virtual nectar card sainsburys selfcheckout tonight worked dream recommend stocard intuitive scanned physical card phone camera using scan interface built app even mini version card scanned problem thats one le thing carry around.
